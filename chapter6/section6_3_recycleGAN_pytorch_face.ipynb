# %% [markdown]
# # 準備

# %% [markdown]
# ドライブ構成
# chapter6/
# 　　　　├ section6_3_recycleGAN_pytorch_face.ipynb (this file)
# 　　　　└ datasets/
# 　　　　　　　　　├fadg0/・・・(fadg0.zipを解答したもの）
# 　　　　　　　　　└faks0/・・・(faks0.zipを解答したもの）

# %%
import google.colab.drive
google.colab.drive.mount('/content/gdrive')
# !ls ./
# Out:
# Mounted at /content/gdrive
# gdrive	sample_data

# %%
# %cd '/content/gdrive/MyDrive/Colab Notebooks/gan_sample/chapter6'
# Out:
# /content/gdrive/MyDrive/colab_GANBook

# %% [markdown]
# ## 入力画像の確認

# %%
import matplotlib.pyplot as plt

# ドメインAの学習データ
img = plt.imread('datasets/fadg0/video/head/001')
plt.imshow(img)

# %%
# ドメインBの学習データ
img = plt.imread('datasets/faks0/video/head/001')
plt.imshow(img)

# %% [markdown]
# ## ライブラリのインストール

# %%
# !pip install torch>=0.4.1
# !pip install torchvision>=0.2.1
# !pip install dominate>=2.3.1
# !pip install visdom>=0.1.8.
# !pip install tensorboard
# !pip install tensorboardX
# Out:
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.6/dist-packages (2.3.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (2.23.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (1.32.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (0.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (1.7.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (0.10.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (1.17.2)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (50.3.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorboard) (0.35.1)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (1.18.5)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (3.12.4)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (1.15.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard) (3.2.2)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard) (2020.6.20)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (1.3.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard) (4.1.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard) (4.6)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from markdown>=2.6.8->tensorboard) (2.0.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard) (3.1.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.6/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard) (3.2.0)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.6/dist-packages (2.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.15.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (3.12.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboardX) (1.18.5)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.8.0->tensorboardX) (50.3.0)

# %% [markdown]
# ## インポート

# %%
import glob
import random
import os
import numpy as np
import time
import datetime
import sys

from torch.utils.data import Dataset
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F

from torch.autograd import Variable
from torch.utils.data import DataLoader
import torch
from visdom import Visdom

import itertools
from PIL import Image

# %%
# ドメインAとドメインBの画像データセット生成クラス
class FaceDatasetSequence(Dataset):
    def __init__(self, root, transforms_=None, unaligned=False, mode='train', 
                 files_A='fadg0/video/', files_B='faks0/video/', skip=0):
        """
        self.files_A: 同じsequence の中では最後の(skip + 1)*2個を除いたものを集める
        params: skipはsequentialなデータを作る際の間引き数. skip=1 で1飛ばしのデータとなる。
        1) get directories in directory A, files in directory B
        2) in loop, append files to file_list except for last (skip + 1)*2 sequence

        """
        self.skip = skip
        self.remove_num = (skip + 1) * 2
        self.transform = transforms.Compose(transforms_)
        self.unaligned = unaligned
        dir_A = os.listdir(path=os.path.join(root, files_A))
        dir_B = os.listdir(path=os.path.join(root, files_B))
        self.files_A = []
        self.files_B = []
        for dir1 in dir_A:
            all_files = sorted(glob.glob(os.path.join(root, files_A, dir1 + '/*')))
            self.files_A += all_files[:- self.remove_num] # 最後から(skip + 1)*2つは削除
        for dir1 in dir_B:
            all_files = sorted(glob.glob(os.path.join(root, files_B, dir1 + '/*')))
            self.files_B += all_files[:- self.remove_num] # 最後から(skip + 1)*2つは削除
        print("len(self.files_A):{}, len(self.files_B):{}".format(len(self.files_A), len(self.files_B)))
        self.count = 1234

    def __getitem__(self, index):
        seed = self.count
        file_A1 = self.files_A[index % len(self.files_A)]
        item_A1, item_A2, item_A3 = self.get_sequential_data(file_A1, seed)
        if self.unaligned:
            num_tmp = np.random.randint(0, len(self.files_B) - 1)
            file_B1 = self.files_B[num_tmp]

        else:
            file_B1 = self.files_B[index % len(self.files_B)]
        item_B1, item_B2, item_B3 = self.get_sequential_data(file_B1, seed+1)
        self.count += 1
        return {'A1': item_A1, 'A2': item_A2, 'A3': item_A3, 'B1': item_B1, 'B2': item_B2, 'B3': item_B3}
        

    def get_sequential_data(self, file1, seed):
        dir_name, file_num = file1.rsplit('/', 1)
        file2 = os.path.join(dir_name, '{:0=3}'.format(int(file_num) + self.skip))
        file3 = os.path.join(dir_name, '{:0=3}'.format(int(file_num) + self.skip * 2))
        random.seed(seed)
        item1 = self.transform(Image.open(file1).convert('RGB'))
        random.seed(seed)
        item2 = self.transform(Image.open(file2).convert('RGB'))
        random.seed(seed)
        item3 = self.transform(Image.open(file3).convert('RGB'))
        return item1, item2, item3

    def __len__(self):
        return max(len(self.files_A), len(self.files_B))

# %% [markdown]
# # ネットワーク定義

# %% [markdown]
# ## Residual Block

# %%
# ResidualBlockの定義
class ResidualBlock(nn.Module):
    def __init__(self, in_features):
        super(ResidualBlock, self).__init__()

        self.conv_block = nn.Sequential(
            nn.ReflectionPad2d(1),
            nn.Conv2d(in_features, in_features, 3),
            nn.InstanceNorm2d(in_features),
            nn.ReLU(inplace=True),
            nn.ReflectionPad2d(1),
            nn.Conv2d(in_features, in_features, 3),
            nn.InstanceNorm2d(in_features)
        )

    def forward(self, x):
        return x + self.conv_block(x)

# %% [markdown]
# ## 生成器

# %%
class Generator(nn.Module):
    def __init__(self, input_nc, output_nc, n_residual_blocks=9):
        super(Generator, self).__init__()

        self.model = nn.Sequential(
            nn.ReflectionPad2d(3),
            nn.Conv2d(input_nc, 64, 7),
            nn.InstanceNorm2d(64),
            nn.ReLU(inplace=True),

            nn.Conv2d(64, 128, 3, stride=2, padding=1),
            nn.InstanceNorm2d(128),
            nn.ReLU(inplace=True),

            nn.Conv2d(128, 256, 3, stride=2, padding=1),
            nn.InstanceNorm2d(256),
            nn.ReLU(inplace=True),

            ResidualBlock(256),
            ResidualBlock(256),
            ResidualBlock(256),
            ResidualBlock(256),
            ResidualBlock(256),
            ResidualBlock(256),
            ResidualBlock(256),
            ResidualBlock(256),
            ResidualBlock(256),

            nn.ConvTranspose2d(256, 128, 3, stride=2, padding=1, output_padding=1),
            nn.InstanceNorm2d(128),
            nn.ReLU(inplace=True),

            nn.ConvTranspose2d(128, 64, 3, stride=2, padding=1, output_padding=1),
            nn.InstanceNorm2d(64),
            nn.ReLU(inplace=True),

            nn.ReflectionPad2d(3),
            nn.Conv2d(64, 3, 7),
            nn.Tanh()
        )

    def forward(self, x):
        return self.model(x)

# %% [markdown]
# ## 識別器

# %%
class Discriminator(nn.Module):
    def __init__(self, input_nc):
        super(Discriminator, self).__init__()

        self.model = nn.Sequential(
            nn.Conv2d(input_nc, 64, 4, stride=2, padding=1),
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(64, 128, 4, stride=2, padding=1),
            nn.InstanceNorm2d(128), 
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(128, 256, 4, stride=2, padding=1),
            nn.InstanceNorm2d(256), 
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(256, 512, 4, padding=1),
            nn.InstanceNorm2d(512), 
            nn.LeakyReLU(0.2, inplace=True),

            nn.Conv2d(512, 1, 4, padding=1)
        )

    def forward(self, x):
        x =  self.model(x)
        # Average pooling and flatten
        return F.avg_pool2d(x, x.size()[2:]).view(x.size()[0], -1)

# %% [markdown]
# ## 生成画像のバッファ

# %%
# 過去の生成データ(50iter分)を保持しておく
class ReplayBuffer():
    def __init__(self, max_size=50):
        self.max_size = max_size
        self.data = []

    def push_and_pop(self, data):
        to_return = []
        for element in data.data:
            #
            element = torch.unsqueeze(element, 0)
            if len(self.data) < self.max_size:
                self.data.append(element)
                to_return.append(element)
            else:
                if random.uniform(0,1) > 0.5:
                    i = random.randint(0, self.max_size-1)
                    to_return.append(self.data[i].clone())
                    self.data[i] = element
                else:
                    to_return.append(element)
        return Variable(torch.cat(to_return))

# %%
class LambdaLR():
    def __init__(self, n_epochs, offset, decay_start_epoch):
        self.n_epochs = n_epochs
        self.offset = offset
        self.decay_start_epoch = decay_start_epoch

    def step(self, epoch):
        return 1.0 - max(0, epoch + self.offset - self.decay_start_epoch)/(self.n_epochs - self.decay_start_epoch)

def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find('Conv') != -1:
        torch.nn.init.normal(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm2d') != -1:
        torch.nn.init.normal(m.weight.data, 1.0, 0.02)
        torch.nn.init.constant(m.bias.data, 0.0)

# %% [markdown]
# ## 予測器

# %%
class ConvUnit(nn.Module):
    def __init__(self, in_channels, out_channels, mid_channels=None):
        super().__init__()
        if not mid_channels:
            mid_channels = out_channels
        self.double_conv = nn.Sequential(
            nn.Conv2d(in_channels, mid_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(mid_channels),
            nn.ReLU(inplace=True),
            nn.Conv2d(mid_channels, out_channels, kernel_size=3, padding=1),
            nn.BatchNorm2d(out_channels),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.double_conv(x)


class Down(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.maxpool_conv = nn.Sequential(
            nn.MaxPool2d(2),
            ConvUnit(in_channels, out_channels)
        )

    def forward(self, x):
        return self.maxpool_conv(x)


class Up(nn.Module):
    def __init__(self, in_channels, out_channels):
        super().__init__()
        self.up = nn.Upsample(scale_factor=2, mode='bilinear', align_corners=True)
        self.conv = ConvUnit(in_channels, out_channels, in_channels // 2)

    def forward(self, x1, x2):
        x1 = self.up(x1)
        diffY = x2.size()[2] - x1.size()[2]
        diffX = x2.size()[3] - x1.size()[3]
        x1 = F.pad(x1, [diffX // 2, diffX - diffX // 2,
                        diffY // 2, diffY - diffY // 2])
        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)


class OutConv(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(OutConv, self).__init__()
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1)

    def forward(self, x):
        return self.conv(x)


class Predictor(nn.Module):
    def __init__(self, input_nc, output_nc):
        super(Predictor, self).__init__()

        self.input_nc = input_nc
        self.output_nc = output_nc
        self.inc = ConvUnit(input_nc, 64)
        self.down1 = Down(64, 128)
        self.down2 = Down(128, 256)
        self.down3 = Down(256, 512)
        self.down4 = Down(512, 512)
        self.up1 = Up(1024, 256)
        self.up2 = Up(512, 128)
        self.up3 = Up(256, 64)
        self.up4 = Up(128, 64)
        self.outc = OutConv(64, output_nc)
        self.tanh = nn.Tanh()

    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)
        x4 = self.down3(x3)
        x5 = self.down4(x4)
        x = self.up1(x5, x4)
        x = self.up2(x, x3)
        x = self.up3(x, x2)
        x = self.up4(x, x1)
        logits = self.outc(x)
        out = self.tanh(logits)
        return out

# %%
# !mkdir -p output
# !ls output

# %% [markdown]
# # 学習

# %% [markdown]
# ## パラメータ設定

# %%
class Opts():
    def __init__(self):
        self.start_epoch = 0
        self.n_epochs = 40
        self.batch_size = 1
        self.dataroot = 'datasets/'
        self.lr = 0.0002
        self.decay_epoch = 200
        self.size = 256
        self.input_nc = 3
        self.output_nc = 3
        self.cpu = False
        self.n_cpu = 8
        self.device_name = "cuda:0"
        self.device = torch.device(self.device_name)
        self.load_weight = False
        self.log_base_name = 'train11'
        self.model_load_path = 'output/recycle/train10/output_model/'
        self.file_a_dir = 'fadg0/video/'
        self.file_b_dir = 'faks0/video/'
        self.id_loss_rate = 5.0
        self.gan_loss_rate = 5.0
        self.recy_loss_rate = 10.0
        self.recu_loss_rate = 10.0
        self.skip = 2

opt = Opts()

# %% [markdown]
# ## TensorboardでのLoss確認

# %%
from torch.utils.tensorboard import SummaryWriter
if not os.path.isdir('./logs'):
    os.mkdir('./logs')
if not os.path.isdir('./logs/recycle'):
    os.mkdir('./logs/recycle')
log_dir = os.path.join('./logs/recycle/', opt.log_base_name)
os.makedirs(log_dir, exist_ok=True)
writer = SummaryWriter(log_dir=log_dir)

# %%
from __future__ import absolute_import, division, print_function, unicode_literals

try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass
  
# %load_ext tensorboard
# %tensorboard --logdir './logs/recycle/train11'

# %% [markdown]
# ## 画像保存・モデル保存のための処理

# %%
def tensor2image(tensor):
    image = 127.5*(tensor[0].cpu().float().detach().numpy() + 1.0)
    if image.shape[0] == 1:
        image = np.tile(image, (3,1,1))
    return image.astype(np.uint8)

def tensor2image_ver2(tensor):
    image = 127.5*(tensor[0].cpu().float().detach().numpy() + 1.0)
    if image.shape[0] == 1:
        image = np.tile(image, (3,1,1))
    image = image.astype(np.uint8).transpose(1,2,0)
    return image

def save_img(img_uint8_real, img_uint8_fake, img_uint8_rec, save_f_path):
    img_uint8 = np.concatenate((img_uint8_real, img_uint8_fake, img_uint8_rec), axis=1)
    img_pil = Image.fromarray(img_uint8)
    img_pil.save(save_f_path)

def save_several_img(img_tuple, save_f_path):
    img_uint8 = np.concatenate(img_tuple, axis=1)
    img_pil = Image.fromarray(img_uint8)
    img_pil.save(save_f_path)

if not os.path.isdir('./output/recycle'):
    os.mkdir('./output/recycle/')
if not os.path.isdir(os.path.join('./output/recycle',opt.log_base_name)):
    os.mkdir(os.path.join('./output/recycle', opt.log_base_name))
if not os.path.isdir(os.path.join('./output/recycle' ,opt.log_base_name, 'output_img')):
    os.mkdir(os.path.join('./output/recycle' ,opt.log_base_name, 'output_img'))
if not os.path.isdir(os.path.join('./output/recycle' ,opt.log_base_name, 'output_model')):
    os.mkdir(os.path.join('./output/recycle' ,opt.log_base_name, 'output_model'))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-4e9f9da5e8cb> in <module>()
#      24 if not os.path.isdir('./output/recycle'):
#      25     os.mkdir('./output/recycle/')
# ---> 26 if not os.path.isdir(os.path.join('./output/recycle',opt.log_base_name)):
#      27     os.mkdir(os.path.join('./output/recycle', opt.log_base_name))
#      28 if not os.path.isdir(os.path.join('./output/recycle' ,opt.log_base_name, 'output_img')):
#
# NameError: name 'opt' is not defined

# %% [markdown]
# ## ネットワーク呼び出し

# %%
# 生成器
netG_A2B = Generator(opt.input_nc, opt.output_nc)
netG_B2A = Generator(opt.output_nc, opt.input_nc)

# 識別器
netD_A = Discriminator(opt.input_nc)
netD_B = Discriminator(opt.output_nc)

# 予測器 ---------------------------- recycle -------------------------------------------------
netP_A = Predictor(opt.input_nc*2, opt.input_nc)
netP_B = Predictor(opt.output_nc*2, opt.output_nc)

# GPU
if not opt.cpu:
    netG_A2B.cuda()
    netG_B2A.cuda()
    netD_A.cuda()
    netD_B.cuda()
    netP_A.cuda() # predictor
    netP_B.cuda() # predictor

# 重みパラメータ初期化
netG_A2B.apply(weights_init_normal)
netG_B2A.apply(weights_init_normal)
netD_A.apply(weights_init_normal)
netD_B.apply(weights_init_normal)

# 保存したモデルのロード
if opt.load_weight is True:
    netG_A2B.load_state_dict(torch.load(os.path.join(opt.model_load_path, "netG_A2B.pth"), map_location="cuda:0"), strict=False)
    netG_B2A.load_state_dict(torch.load(os.path.join(opt.model_load_path, "netG_B2A.pth"), map_location="cuda:0"), strict=False)
    netD_A.load_state_dict(torch.load(os.path.join(opt.model_load_path, "netD_A.pth"), map_location="cuda:0"), strict=False)
    netD_B.load_state_dict(torch.load(os.path.join(opt.model_load_path, "netD_B.pth"), map_location="cuda:0"), strict=False)
    netP_A.load_state_dict(torch.load(os.path.join(opt.model_load_path, "netP_A.pth"), map_location="cuda:0"), strict=False) # predictor
    netP_B.load_state_dict(torch.load(os.path.join(opt.model_load_path, "netP_B.pth"), map_location="cuda:0"), strict=False) # predictor

# 損失関数
criterion_GAN = torch.nn.MSELoss()
criterion_recycle = torch.nn.L1Loss()
criterion_identity = torch.nn.L1Loss()
criterion_recurrent = torch.nn.L1Loss() # predictor


# Optimizers & LR schedulers
optimizer_PG = torch.optim.Adam(itertools.chain(netG_A2B.parameters(), netG_B2A.parameters(), netP_A.parameters(),
                                               netP_B.parameters()), lr=opt.lr, betas=(0.5, 0.999))
optimizer_D_A = torch.optim.Adam(netD_A.parameters(), lr=opt.lr, betas=(0.5, 0.999))
optimizer_D_B = torch.optim.Adam(netD_B.parameters(), lr=opt.lr, betas=(0.5, 0.999))

lr_scheduler_PG = torch.optim.lr_scheduler.LambdaLR(optimizer_PG, lr_lambda=LambdaLR(opt.n_epochs, opt.start_epoch, opt.decay_epoch).step)
lr_scheduler_D_A = torch.optim.lr_scheduler.LambdaLR(optimizer_D_A, lr_lambda=LambdaLR(opt.n_epochs, opt.start_epoch, opt.decay_epoch).step)
lr_scheduler_D_B = torch.optim.lr_scheduler.LambdaLR(optimizer_D_B, lr_lambda=LambdaLR(opt.n_epochs, opt.start_epoch, opt.decay_epoch).step)

# 入出力メモリ確保
Tensor = torch.cuda.FloatTensor if not opt.cpu else torch.Tensor
input_A1 = Tensor(opt.batch_size, opt.input_nc, opt.size, opt.size)
input_A2 = Tensor(opt.batch_size, opt.input_nc, opt.size, opt.size)
input_A3 = Tensor(opt.batch_size, opt.input_nc, opt.size, opt.size)
input_B1 = Tensor(opt.batch_size, opt.output_nc, opt.size, opt.size)
input_B2 = Tensor(opt.batch_size, opt.output_nc, opt.size, opt.size)
input_B3 = Tensor(opt.batch_size, opt.output_nc, opt.size, opt.size)
target_real = Variable(Tensor(opt.batch_size).fill_(1.0), requires_grad=False)
target_fake = Variable(Tensor(opt.batch_size).fill_(0.0), requires_grad=False)

# 過去データ分のメモリ確保
fake_A_buffer = ReplayBuffer()
fake_B_buffer = ReplayBuffer()

# データローダー
transforms_ = [ transforms.Resize(int(opt.size*1.12), Image.BICUBIC), 
                transforms.RandomCrop(opt.size), 
                #transforms.RandomHorizontalFlip(),
                transforms.ToTensor(),
                transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5)) ]
# dataloader = DataLoader(FaceDatasetSequence(opt.dataroot, transforms_=transforms_, unaligned=True, 
dataloader = DataLoader(FaceDatasetSequence(opt.dataroot, transforms_=transforms_, unaligned=False, 
                                            files_A=opt.file_a_dir, files_B=opt.file_b_dir, skip=opt.skip), 
                        batch_size=opt.batch_size, shuffle=True, num_workers=opt.n_cpu)

print("num dataloader= {}".format(len(dataloader)))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   del sys.path[0]
# len(self.files_A):2551, len(self.files_B):1969
# num dataloader= 2551

# %%
def save_loss(train_info, batches_done):
    """
    lossの保存
    """
    for k, v in train_info.items():
        writer.add_scalar(k, v, batches_done)

# %% [markdown]
# ## 学習の開始

# %%
for epoch in range(opt.start_epoch, opt.n_epochs):
    for i, batch in enumerate(dataloader):
        # モデルの入力
        real_A1 = Variable(input_A1.copy_(batch['A1']))
        real_A2 = Variable(input_A2.copy_(batch['A2']))
        real_A3 = Variable(input_A3.copy_(batch['A3']))

        real_B1 = Variable(input_B1.copy_(batch['B1']))
        real_B2 = Variable(input_B2.copy_(batch['B2']))
        real_B3 = Variable(input_B3.copy_(batch['B3']))

        ##### 生成器A2B、B2Aの処理 #####
        optimizer_PG.zero_grad()

        # 同一性損失の計算（Identity loss)
        # G_A2B(B)はBと一致
        same_B1 = netG_A2B(real_B1)
        loss_identity_B = criterion_identity(same_B1, real_B1)*opt.id_loss_rate
        # G_B2A(A)はAと一致
        same_A1 = netG_B2A(real_A1)
        loss_identity_A = criterion_identity(same_A1, real_A1)*opt.id_loss_rate

        # 敵対的損失（GAN loss）
        fake_B1 = netG_A2B(real_A1)
        pred_fake_B1 = netD_B(fake_B1)
        loss_GAN_A2B1 = criterion_GAN(pred_fake_B1, target_real)*opt.gan_loss_rate

        fake_B2 = netG_A2B(real_A2)
        pred_fake_B2 = netD_B(fake_B2)
        loss_GAN_A2B2 = criterion_GAN(pred_fake_B2, target_real)*opt.gan_loss_rate

        fake_B3 = netG_A2B(real_A3)
        pred_fake_B3 = netD_B(fake_B3)
        loss_GAN_A2B3 = criterion_GAN(pred_fake_B3, target_real)*opt.gan_loss_rate

        fake_A1 = netG_B2A(real_B1)
        pred_fake_A1 = netD_A(fake_A1)
        loss_GAN_B2A1 = criterion_GAN(pred_fake_A1, target_real)*opt.gan_loss_rate

        fake_A2 = netG_B2A(real_B2)
        pred_fake_A2 = netD_A(fake_A2)
        loss_GAN_B2A2 = criterion_GAN(pred_fake_A2, target_real)*opt.gan_loss_rate

        fake_A3 = netG_B2A(real_B3)
        pred_fake_A3 = netD_A(fake_A3)
        loss_GAN_B2A3 = criterion_GAN(pred_fake_A3, target_real)*opt.gan_loss_rate

        # サイクル一貫性損失（Cycle-consistency loss）
        fake_B12 = torch.cat((fake_B1, fake_B2), dim=1)
        fake_B3_pred = netP_B(fake_B12)
        recovered_A3 = netG_B2A(fake_B3_pred)
        loss_recycle_ABA = criterion_recycle(recovered_A3, real_A3)*opt.recy_loss_rate

        fake_A12 = torch.cat((fake_A1, fake_A2), dim=1)
        fake_A3_pred = netP_A(fake_A12)
        recovered_B3 = netG_A2B(fake_A3_pred)
        loss_recycle_BAB = criterion_recycle(recovered_B3, real_B3)*opt.recy_loss_rate

        # Recurrent loss
        real_A12 = torch.cat((real_A1, real_A2), dim=1)
        pred_A3 = netP_A(real_A12)
        loss_recurrent_A = criterion_recurrent(pred_A3, real_A3)*opt.recu_loss_rate

        real_B12 = torch.cat((real_B1, real_B2), dim=1)
        pred_B3 = netP_B(real_B12)
        loss_recurrent_B = criterion_recurrent(pred_B3, real_B3)*opt.recu_loss_rate


        # 生成器の合計損失関数（Total loss）
        loss_PG = loss_identity_A + loss_identity_B \
                + loss_GAN_A2B1 + loss_GAN_A2B2 + loss_GAN_A2B3 + loss_GAN_B2A1 + loss_GAN_B2A2 + loss_GAN_B2A3 \
                + loss_recycle_ABA + loss_recycle_BAB \
                + loss_recurrent_A + loss_recurrent_B
        loss_PG.backward()
        
        optimizer_PG.step()

        # 保存用画像のための処理
        fake_A1_clone = fake_A1.clone()
        fake_B1_clone = fake_B1.clone()
        fake_A2_clone = fake_A2.clone()
        fake_B2_clone = fake_B2.clone()
        fake_A3_clone = fake_A3.clone()
        fake_B3_clone = fake_B3.clone()
        real_A1_clone = real_A1.clone()
        real_B1_clone = real_B1.clone()
        real_A2_clone = real_A2.clone()
        real_B2_clone = real_B2.clone()
        real_A3_clone = real_A3.clone()
        real_B3_clone = real_B3.clone()
        recovered_A1 = netG_B2A(fake_B1_clone)
        recovered_B1 = netG_A2B(fake_A1_clone)

        ##### ドメインAの識別器 #####
        optimizer_D_A.zero_grad()

        # ドメインAの本物画像の識別結果（Real loss）
        pred_real_A1 = netD_A(real_A1)
        loss_D_real_A1 = criterion_GAN(pred_real_A1, target_real)
        pred_real_A2 = netD_A(real_A2)
        loss_D_real_A2 = criterion_GAN(pred_real_A2, target_real)
        pred_real_A3 = netD_A(real_A3)
        loss_D_real_A3 = criterion_GAN(pred_real_A3, target_real)

        # ドメインAの生成画像の識別結果（Fake loss）
        fake_A1 = fake_A_buffer.push_and_pop(fake_A1)
        pred_fake_A1 = netD_A(fake_A1.detach())
        loss_D_fake_A1 = criterion_GAN(pred_fake_A1, target_fake)
        
        fake_A2 = fake_A_buffer.push_and_pop(fake_A2)
        pred_fake_A2 = netD_A(fake_A2.detach())
        loss_D_fake_A2 = criterion_GAN(pred_fake_A2, target_fake)
        
        fake_A3 = fake_A_buffer.push_and_pop(fake_A3)
        pred_fake_A3 = netD_A(fake_A3.detach())
        loss_D_fake_A3 = criterion_GAN(pred_fake_A3, target_fake)

        # 識別器（ドメインA）の合計損失（Total loss）
        loss_D_A = (loss_D_real_A1 + loss_D_real_A2 + loss_D_real_A3 + loss_D_fake_A1 + loss_D_fake_A2 + loss_D_fake_A3)*0.5
        loss_D_A.backward()

        optimizer_D_A.step()

        ##### ドメインBの識別器 #####
        optimizer_D_B.zero_grad()

        # ドメインBの本物画像の識別結果（Real loss）
        pred_real_B1 = netD_B(real_B1)
        loss_D_real_B1 = criterion_GAN(pred_real_B1, target_real)
        pred_real_B2 = netD_B(real_B2)
        loss_D_real_B2 = criterion_GAN(pred_real_B2, target_real)
        pred_real_B3 = netD_B(real_B3)
        loss_D_real_B3 = criterion_GAN(pred_real_B3, target_real)
        
        # ドメインBの生成画像の識別結果（Fake loss）
        fake_B1 = fake_A_buffer.push_and_pop(fake_B1)
        pred_fake_B1 = netD_B(fake_B1.detach())
        loss_D_fake_B1 = criterion_GAN(pred_fake_B1, target_fake)

        fake_B2 = fake_A_buffer.push_and_pop(fake_B2)
        pred_fake_B2 = netD_B(fake_B2.detach())
        loss_D_fake_B2 = criterion_GAN(pred_fake_B2, target_fake)

        fake_B3 = fake_A_buffer.push_and_pop(fake_B3)
        pred_fake_B3 = netD_B(fake_B3.detach())
        loss_D_fake_B3 = criterion_GAN(pred_fake_B3, target_fake)

        # 識別器（ドメインB）の合計損失（Total loss）
        loss_D_B = (loss_D_real_B1 + loss_D_real_B2 + loss_D_real_B3 + loss_D_fake_B1 + loss_D_fake_B2 + loss_D_fake_B3)*0.5
        loss_D_B.backward()

        optimizer_D_B.step()
        ###################################

        if i % 20 == 0:
            print('Epoch[{}]({}/{}) loss_PG: {:.3f} loss_G_identity: {:.3f} loss_G_GAN: {:.3} loss_G_recycle: {:.3f} loss_D: {:.3f}'.format(
                epoch, i, len(dataloader), loss_PG, (loss_identity_A + loss_identity_B),
                (loss_GAN_A2B1+loss_GAN_A2B2+loss_GAN_A2B3+loss_GAN_B2A1+loss_GAN_B2A2+loss_GAN_B2A3),
                (loss_recycle_ABA + loss_recycle_BAB), (loss_D_A + loss_D_B)))
            print( 'loss_recurrent: {:.3f} loss_D_A_fake: {:.3f} loss_D_A_real: {:.3f} loss_D_B_fake: {:.3f} loss_D_B_real: {:.3f}'.format(
                    (loss_recurrent_A + loss_recurrent_B),
                    (loss_D_fake_A1 + loss_D_fake_A2 + loss_D_fake_A3), (loss_D_real_A1 + loss_D_real_A2 + loss_D_real_A3),
                    (loss_D_fake_B1 + loss_D_fake_B2 + loss_D_fake_B3), (loss_D_real_B1 + loss_D_real_B2 + loss_D_real_B3)))

        train_info = {
            'epoch': epoch, 
            'batch_num': i, 
            'lossG': loss_PG.item(),
            'lossG_identity': (loss_identity_A.item() + loss_identity_B.item()),
            'lossG_GAN': (loss_GAN_A2B1.item()+loss_GAN_A2B2.item()+loss_GAN_A2B3.item()+loss_GAN_B2A1.item()+loss_GAN_B2A2.item()+loss_GAN_B2A3.item()),
            'lossG_recycle': (loss_recycle_ABA.item() + loss_recycle_BAB.item()),
            'lossG_recurrent': (loss_recurrent_A.item() + loss_recurrent_B.item()),
            'lossD': (loss_D_fake_A1.item() + loss_D_fake_A2.item() + loss_D_fake_A3.item()
                      + loss_D_real_A1.item() + loss_D_real_A2.item() + loss_D_real_A3.item()
                      + loss_D_fake_B1.item() + loss_D_fake_B2.item() + loss_D_fake_B3.item()
                      +loss_D_real_B1.item() + loss_D_real_B2.item() + loss_D_real_B3.item()), 
            }

        batches_done = (epoch - 1) * len(dataloader) + i
        save_loss(train_info, batches_done)

        if i == 0:
            # 生成画像の保存
            realb1_img_uint8 = tensor2image_ver2(real_B1_clone)
            fakea1_img_uint8 = tensor2image_ver2(fake_A1_clone)
            rec_b1_img_uint8 = tensor2image_ver2(recovered_B1)
            save_several_img((realb1_img_uint8, fakea1_img_uint8, rec_b1_img_uint8),
                     os.path.join('output/recycle', opt.log_base_name, 'output_img/img_BAB_e{}.png'.format(epoch)))

            reala1_img_uint8 = tensor2image_ver2(real_A1_clone)
            fakeb1_img_uint8 = tensor2image_ver2(fake_B1_clone)
            rec_a1_img_uint8 = tensor2image_ver2(recovered_A1)
            save_several_img((reala1_img_uint8, fakeb1_img_uint8, rec_a1_img_uint8),
                     os.path.join('output/recycle', opt.log_base_name, 'output_img/img_ABA_e{}.png'.format(epoch)))
            
            same_a1_img_uint8 = tensor2image_ver2(same_A1)
            save_several_img((reala1_img_uint8, same_a1_img_uint8),
                     os.path.join('output/recycle', opt.log_base_name, 'output_img/img_ide_A_e{}.png'.format(epoch)))

            same_b1_img_uint8 = tensor2image_ver2(same_B1)
            save_several_img((realb1_img_uint8, same_b1_img_uint8),
                     os.path.join('output/recycle', opt.log_base_name, 'output_img/img_ideB_e{}.png'.format(epoch)))


            pred_A3_img_uint8 = tensor2image_ver2(pred_A3)
            real_A1_img_uint8 = tensor2image_ver2(real_A1_clone)
            real_A2_img_uint8 = tensor2image_ver2(real_A2_clone)
            real_A3_img_uint8 = tensor2image_ver2(real_A3_clone)
            save_several_img((real_A1_img_uint8, real_A2_img_uint8, pred_A3_img_uint8, real_A3_img_uint8),
                     os.path.join('output/recycle', opt.log_base_name, 'output_img/img_predA_e{}.png'.format(epoch)))

            pred_B3_img_uint8 = tensor2image_ver2(pred_B3)
            real_B1_img_uint8 = tensor2image_ver2(real_B1_clone)
            real_B2_img_uint8 = tensor2image_ver2(real_B2_clone)
            real_B3_img_uint8 = tensor2image_ver2(real_B3_clone)
            save_several_img((real_B1_img_uint8, real_B2_img_uint8, pred_B3_img_uint8, real_B3_img_uint8),
                     os.path.join('output/recycle', opt.log_base_name, 'output_img/img_predB_e{}.png'.format(epoch)))

            fp_A3_img_uint8 = tensor2image_ver2(fake_A3_pred)
            rec_B3_img_uint8 = tensor2image_ver2(recovered_B3)
            save_several_img((realb1_img_uint8, fakea1_img_uint8, fp_A3_img_uint8, rec_B3_img_uint8),
                     os.path.join('output/recycle', opt.log_base_name, 'output_img/img_BAPB_e{}.png'.format(epoch)))

            fp_B3_img_uint8 = tensor2image_ver2(fake_B3_pred)
            rec_A3_img_uint8 = tensor2image_ver2(recovered_A3)
            save_several_img((reala1_img_uint8, fakeb1_img_uint8, fp_B3_img_uint8, rec_A3_img_uint8),
                     os.path.join('output/recycle', opt.log_base_name, 'output_img/img_ABPA_e{}.png'.format(epoch)))

    # Update learning rates
    lr_scheduler_PG.step()
    lr_scheduler_D_A.step()
    lr_scheduler_D_B.step()

    # Save models checkpoints
    torch.save(netG_A2B.state_dict(), os.path.join('output/recycle/', opt.log_base_name, 'output_model/netG_A2B.pth'))
    torch.save(netG_B2A.state_dict(), os.path.join('output/recycle/', opt.log_base_name, 'output_model/netG_B2A.pth'))
    torch.save(netD_A.state_dict(), os.path.join('output/recycle/', opt.log_base_name, 'output_model/netD_A.pth'))
    torch.save(netD_B.state_dict(), os.path.join('output/recycle/', opt.log_base_name, 'output_model/netD_B.pth'))
    torch.save(netP_A.state_dict(), os.path.join('output/recycle/', opt.log_base_name, 'output_model/netP_A.pth')) # predictor
    torch.save(netP_B.state_dict(), os.path.join('output/recycle/', opt.log_base_name, 'output_model/netP_B.pth')) # predictor
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/modules/loss.py:445: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# Epoch[0](0/2551) loss_PG: 17.153 loss_G_identity: 0.332 loss_G_GAN: 15.2 loss_G_recycle: 1.079 loss_D: 0.914
# loss_recurrent: 0.521 loss_D_A_fake: 0.006 loss_D_A_real: 0.189 loss_D_B_fake: 1.421 loss_D_B_real: 0.211
# Epoch[0](20/2551) loss_PG: 13.395 loss_G_identity: 0.259 loss_G_GAN: 12.1 loss_G_recycle: 0.702 loss_D: 1.212
# loss_recurrent: 0.371 loss_D_A_fake: 0.200 loss_D_A_real: 1.798 loss_D_B_fake: 0.406 loss_D_B_real: 0.021
# Epoch[0](40/2551) loss_PG: 12.802 loss_G_identity: 0.267 loss_G_GAN: 11.3 loss_G_recycle: 0.801 loss_D: 1.417
# loss_recurrent: 0.474 loss_D_A_fake: 0.630 loss_D_A_real: 0.014 loss_D_B_fake: 0.210 loss_D_B_real: 1.981
# Epoch[0](60/2551) loss_PG: 9.461 loss_G_identity: 0.335 loss_G_GAN: 7.39 loss_G_recycle: 1.018 loss_D: 0.939
# loss_recurrent: 0.719 loss_D_A_fake: 0.419 loss_D_A_real: 0.096 loss_D_B_fake: 0.944 loss_D_B_real: 0.419
# Epoch[0](80/2551) loss_PG: 5.765 loss_G_identity: 0.294 loss_G_GAN: 4.11 loss_G_recycle: 0.858 loss_D: 0.701
# loss_recurrent: 0.500 loss_D_A_fake: 0.304 loss_D_A_real: 0.042 loss_D_B_fake: 1.048 loss_D_B_real: 0.008
# Epoch[0](100/2551) loss_PG: 11.067 loss_G_identity: 0.290 loss_G_GAN: 9.34 loss_G_recycle: 0.906 loss_D: 0.458
# loss_recurrent: 0.535 loss_D_A_fake: 0.686 loss_D_A_real: 0.002 loss_D_B_fake: 0.207 loss_D_B_real: 0.022
# Epoch[0](120/2551) loss_PG: 14.873 loss_G_identity: 0.286 loss_G_GAN: 13.1 loss_G_recycle: 0.864 loss_D: 0.831
# loss_recurrent: 0.574 loss_D_A_fake: 0.131 loss_D_A_real: 0.779 loss_D_B_fake: 0.750 loss_D_B_real: 0.003
# Epoch[0](140/2551) loss_PG: 11.451 loss_G_identity: 0.288 loss_G_GAN: 9.71 loss_G_recycle: 0.885 loss_D: 0.955
# loss_recurrent: 0.566 loss_D_A_fake: 0.316 loss_D_A_real: 0.000 loss_D_B_fake: 0.154 loss_D_B_real: 1.440
# Epoch[0](160/2551) loss_PG: 11.163 loss_G_identity: 0.357 loss_G_GAN: 9.47 loss_G_recycle: 0.886 loss_D: 1.104
# loss_recurrent: 0.453 loss_D_A_fake: 0.415 loss_D_A_real: 1.261 loss_D_B_fake: 0.531 loss_D_B_real: 0.001
# Epoch[0](180/2551) loss_PG: 14.018 loss_G_identity: 0.290 loss_G_GAN: 12.4 loss_G_recycle: 0.920 loss_D: 0.739
# loss_recurrent: 0.449 loss_D_A_fake: 0.361 loss_D_A_real: 0.931 loss_D_B_fake: 0.170 loss_D_B_real: 0.016
# Epoch[0](200/2551) loss_PG: 13.684 loss_G_identity: 0.288 loss_G_GAN: 12.2 loss_G_recycle: 0.741 loss_D: 0.728
# loss_recurrent: 0.410 loss_D_A_fake: 0.217 loss_D_A_real: 0.042 loss_D_B_fake: 0.158 loss_D_B_real: 1.040
# Epoch[0](220/2551) loss_PG: 11.672 loss_G_identity: 0.240 loss_G_GAN: 10.4 loss_G_recycle: 0.666 loss_D: 1.022
# loss_recurrent: 0.382 loss_D_A_fake: 0.606 loss_D_A_real: 0.014 loss_D_B_fake: 0.183 loss_D_B_real: 1.240
# Epoch[0](240/2551) loss_PG: 11.237 loss_G_identity: 0.260 loss_G_GAN: 9.77 loss_G_recycle: 0.818 loss_D: 1.101
# loss_recurrent: 0.390 loss_D_A_fake: 0.382 loss_D_A_real: 0.001 loss_D_B_fake: 0.632 loss_D_B_real: 1.186
# Epoch[0](260/2551) loss_PG: 22.795 loss_G_identity: 0.267 loss_G_GAN: 21.4 loss_G_recycle: 0.742 loss_D: 1.650
# loss_recurrent: 0.417 loss_D_A_fake: 0.089 loss_D_A_real: 1.766 loss_D_B_fake: 0.227 loss_D_B_real: 1.218
# Epoch[0](280/2551) loss_PG: 13.008 loss_G_identity: 0.281 loss_G_GAN: 11.5 loss_G_recycle: 0.736 loss_D: 1.808
# loss_recurrent: 0.494 loss_D_A_fake: 0.118 loss_D_A_real: 2.030 loss_D_B_fake: 0.842 loss_D_B_real: 0.627
# Epoch[0](300/2551) loss_PG: 3.413 loss_G_identity: 0.242 loss_G_GAN: 2.11 loss_G_recycle: 0.676 loss_D: 0.977
# loss_recurrent: 0.386 loss_D_A_fake: 0.736 loss_D_A_real: 0.258 loss_D_B_fake: 0.560 loss_D_B_real: 0.400
# Epoch[0](320/2551) loss_PG: 13.142 loss_G_identity: 0.347 loss_G_GAN: 11.2 loss_G_recycle: 1.031 loss_D: 0.308
# loss_recurrent: 0.521 loss_D_A_fake: 0.301 loss_D_A_real: 0.001 loss_D_B_fake: 0.310 loss_D_B_real: 0.004
# Epoch[0](340/2551) loss_PG: 21.964 loss_G_identity: 0.241 loss_G_GAN: 20.3 loss_G_recycle: 0.782 loss_D: 2.213
# loss_recurrent: 0.600 loss_D_A_fake: 0.174 loss_D_A_real: 2.358 loss_D_B_fake: 0.138 loss_D_B_real: 1.756
# Epoch[0](360/2551) loss_PG: 13.995 loss_G_identity: 0.263 loss_G_GAN: 12.5 loss_G_recycle: 0.789 loss_D: 1.013
# loss_recurrent: 0.413 loss_D_A_fake: 0.249 loss_D_A_real: 1.438 loss_D_B_fake: 0.336 loss_D_B_real: 0.003
# Epoch[0](380/2551) loss_PG: 6.775 loss_G_identity: 0.281 loss_G_GAN: 5.16 loss_G_recycle: 0.861 loss_D: 1.083
# loss_recurrent: 0.468 loss_D_A_fake: 0.886 loss_D_A_real: 0.713 loss_D_B_fake: 0.566 loss_D_B_real: 0.001
# Epoch[0](400/2551) loss_PG: 15.168 loss_G_identity: 0.307 loss_G_GAN: 13.4 loss_G_recycle: 0.929 loss_D: 1.562
# loss_recurrent: 0.534 loss_D_A_fake: 0.917 loss_D_A_real: 0.080 loss_D_B_fake: 0.038 loss_D_B_real: 2.089
# Epoch[0](420/2551) loss_PG: 8.735 loss_G_identity: 0.302 loss_G_GAN: 7.01 loss_G_recycle: 0.932 loss_D: 1.400
# loss_recurrent: 0.491 loss_D_A_fake: 0.745 loss_D_A_real: 1.492 loss_D_B_fake: 0.318 loss_D_B_real: 0.245
# Epoch[0](440/2551) loss_PG: 13.677 loss_G_identity: 0.329 loss_G_GAN: 11.8 loss_G_recycle: 0.951 loss_D: 1.036
# loss_recurrent: 0.549 loss_D_A_fake: 0.419 loss_D_A_real: 0.723 loss_D_B_fake: 0.214 loss_D_B_real: 0.715
# Epoch[0](460/2551) loss_PG: 8.271 loss_G_identity: 0.281 loss_G_GAN: 6.79 loss_G_recycle: 0.767 loss_D: 0.795
# loss_recurrent: 0.432 loss_D_A_fake: 0.689 loss_D_A_real: 0.652 loss_D_B_fake: 0.228 loss_D_B_real: 0.022
# Epoch[0](480/2551) loss_PG: 9.560 loss_G_identity: 0.272 loss_G_GAN: 8.15 loss_G_recycle: 0.747 loss_D: 0.599
# loss_recurrent: 0.391 loss_D_A_fake: 0.526 loss_D_A_real: 0.384 loss_D_B_fake: 0.283 loss_D_B_real: 0.004
# Epoch[0](500/2551) loss_PG: 9.662 loss_G_identity: 0.263 loss_G_GAN: 8.28 loss_G_recycle: 0.708 loss_D: 0.738
# loss_recurrent: 0.405 loss_D_A_fake: 0.434 loss_D_A_real: 0.020 loss_D_B_fake: 0.513 loss_D_B_real: 0.509
# Epoch[0](520/2551) loss_PG: 13.311 loss_G_identity: 0.284 loss_G_GAN: 11.4 loss_G_recycle: 0.961 loss_D: 0.490
# loss_recurrent: 0.671 loss_D_A_fake: 0.710 loss_D_A_real: 0.137 loss_D_B_fake: 0.092 loss_D_B_real: 0.042
# Epoch[0](540/2551) loss_PG: 10.535 loss_G_identity: 0.340 loss_G_GAN: 8.49 loss_G_recycle: 1.065 loss_D: 0.826
# loss_recurrent: 0.640 loss_D_A_fake: 0.555 loss_D_A_real: 0.114 loss_D_B_fake: 0.656 loss_D_B_real: 0.327
# Epoch[0](560/2551) loss_PG: 8.243 loss_G_identity: 0.219 loss_G_GAN: 7.02 loss_G_recycle: 0.637 loss_D: 1.398
# loss_recurrent: 0.369 loss_D_A_fake: 0.150 loss_D_A_real: 0.994 loss_D_B_fake: 0.711 loss_D_B_real: 0.941
# Epoch[0](580/2551) loss_PG: 21.744 loss_G_identity: 0.312 loss_G_GAN: 20.2 loss_G_recycle: 0.873 loss_D: 0.612
# loss_recurrent: 0.368 loss_D_A_fake: 0.005 loss_D_A_real: 0.482 loss_D_B_fake: 0.736 loss_D_B_real: 0.000
# Epoch[0](600/2551) loss_PG: 8.398 loss_G_identity: 0.281 loss_G_GAN: 7.01 loss_G_recycle: 0.727 loss_D: 1.159
# loss_recurrent: 0.380 loss_D_A_fake: 0.905 loss_D_A_real: 0.700 loss_D_B_fake: 0.641 loss_D_B_real: 0.072
# Epoch[0](620/2551) loss_PG: 12.482 loss_G_identity: 0.306 loss_G_GAN: 10.9 loss_G_recycle: 0.870 loss_D: 0.756
# loss_recurrent: 0.369 loss_D_A_fake: 0.301 loss_D_A_real: 0.005 loss_D_B_fake: 0.788 loss_D_B_real: 0.418
# Epoch[0](640/2551) loss_PG: 8.360 loss_G_identity: 0.297 loss_G_GAN: 6.63 loss_G_recycle: 0.944 loss_D: 0.497
# loss_recurrent: 0.488 loss_D_A_fake: 0.489 loss_D_A_real: 0.006 loss_D_B_fake: 0.494 loss_D_B_real: 0.006
# Epoch[0](660/2551) loss_PG: 8.644 loss_G_identity: 0.287 loss_G_GAN: 7.23 loss_G_recycle: 0.755 loss_D: 0.719
# loss_recurrent: 0.373 loss_D_A_fake: 0.383 loss_D_A_real: 0.855 loss_D_B_fake: 0.201 loss_D_B_real: 0.000
# Epoch[0](680/2551) loss_PG: 21.726 loss_G_identity: 0.376 loss_G_GAN: 20.0 loss_G_recycle: 0.936 loss_D: 1.343
# loss_recurrent: 0.408 loss_D_A_fake: 0.028 loss_D_A_real: 2.314 loss_D_B_fake: 0.338 loss_D_B_real: 0.007
# Epoch[0](700/2551) loss_PG: 11.916 loss_G_identity: 0.391 loss_G_GAN: 9.89 loss_G_recycle: 1.159 loss_D: 0.670
# loss_recurrent: 0.475 loss_D_A_fake: 0.920 loss_D_A_real: 0.185 loss_D_B_fake: 0.202 loss_D_B_real: 0.033
# Epoch[0](720/2551) loss_PG: 16.474 loss_G_identity: 0.347 loss_G_GAN: 14.8 loss_G_recycle: 0.980 loss_D: 0.433
# loss_recurrent: 0.362 loss_D_A_fake: 0.096 loss_D_A_real: 0.142 loss_D_B_fake: 0.616 loss_D_B_real: 0.012
# Epoch[0](740/2551) loss_PG: 11.620 loss_G_identity: 0.359 loss_G_GAN: 9.69 loss_G_recycle: 1.038 loss_D: 0.729
# loss_recurrent: 0.531 loss_D_A_fake: 0.192 loss_D_A_real: 0.014 loss_D_B_fake: 1.124 loss_D_B_real: 0.127
# Epoch[0](760/2551) loss_PG: 18.456 loss_G_identity: 0.302 loss_G_GAN: 16.7 loss_G_recycle: 0.924 loss_D: 0.688
# loss_recurrent: 0.483 loss_D_A_fake: 0.002 loss_D_A_real: 0.623 loss_D_B_fake: 0.718 loss_D_B_real: 0.033
# Epoch[0](780/2551) loss_PG: 15.801 loss_G_identity: 0.344 loss_G_GAN: 14.1 loss_G_recycle: 0.936 loss_D: 1.414
# loss_recurrent: 0.381 loss_D_A_fake: 0.148 loss_D_A_real: 2.112 loss_D_B_fake: 0.417 loss_D_B_real: 0.150
# Epoch[0](800/2551) loss_PG: 16.140 loss_G_identity: 0.250 loss_G_GAN: 14.7 loss_G_recycle: 0.730 loss_D: 0.710
# loss_recurrent: 0.447 loss_D_A_fake: 0.097 loss_D_A_real: 0.140 loss_D_B_fake: 0.317 loss_D_B_real: 0.865
# Epoch[0](820/2551) loss_PG: 15.882 loss_G_identity: 0.265 loss_G_GAN: 14.5 loss_G_recycle: 0.745 loss_D: 0.323
# loss_recurrent: 0.410 loss_D_A_fake: 0.328 loss_D_A_real: 0.074 loss_D_B_fake: 0.239 loss_D_B_real: 0.006
# Epoch[0](840/2551) loss_PG: 13.001 loss_G_identity: 0.322 loss_G_GAN: 11.1 loss_G_recycle: 0.965 loss_D: 1.852
# loss_recurrent: 0.581 loss_D_A_fake: 0.202 loss_D_A_real: 2.809 loss_D_B_fake: 0.673 loss_D_B_real: 0.018
# Epoch[0](860/2551) loss_PG: 9.116 loss_G_identity: 0.246 loss_G_GAN: 7.76 loss_G_recycle: 0.707 loss_D: 1.316
# loss_recurrent: 0.400 loss_D_A_fake: 0.904 loss_D_A_real: 0.233 loss_D_B_fake: 0.409 loss_D_B_real: 1.086
# Epoch[0](880/2551) loss_PG: 13.390 loss_G_identity: 0.265 loss_G_GAN: 12.0 loss_G_recycle: 0.756 loss_D: 0.497
# loss_recurrent: 0.400 loss_D_A_fake: 0.532 loss_D_A_real: 0.097 loss_D_B_fake: 0.201 loss_D_B_real: 0.165
# Epoch[0](900/2551) loss_PG: 19.184 loss_G_identity: 0.278 loss_G_GAN: 17.2 loss_G_recycle: 1.087 loss_D: 0.555
# loss_recurrent: 0.630 loss_D_A_fake: 0.038 loss_D_A_real: 0.355 loss_D_B_fake: 0.673 loss_D_B_real: 0.045
# Epoch[0](920/2551) loss_PG: 13.057 loss_G_identity: 0.313 loss_G_GAN: 11.3 loss_G_recycle: 0.930 loss_D: 1.184
# loss_recurrent: 0.538 loss_D_A_fake: 0.183 loss_D_A_real: 1.741 loss_D_B_fake: 0.341 loss_D_B_real: 0.103
# Epoch[0](940/2551) loss_PG: 13.680 loss_G_identity: 0.258 loss_G_GAN: 12.2 loss_G_recycle: 0.801 loss_D: 1.457
# loss_recurrent: 0.434 loss_D_A_fake: 0.241 loss_D_A_real: 0.961 loss_D_B_fake: 0.209 loss_D_B_real: 1.503
# Epoch[0](960/2551) loss_PG: 19.066 loss_G_identity: 0.287 loss_G_GAN: 17.3 loss_G_recycle: 0.931 loss_D: 0.932
# loss_recurrent: 0.580 loss_D_A_fake: 0.242 loss_D_A_real: 1.237 loss_D_B_fake: 0.118 loss_D_B_real: 0.266
# Epoch[0](980/2551) loss_PG: 15.731 loss_G_identity: 0.291 loss_G_GAN: 14.0 loss_G_recycle: 0.880 loss_D: 0.418
# loss_recurrent: 0.511 loss_D_A_fake: 0.116 loss_D_A_real: 0.390 loss_D_B_fake: 0.322 loss_D_B_real: 0.009
# Epoch[0](1000/2551) loss_PG: 16.828 loss_G_identity: 0.308 loss_G_GAN: 15.2 loss_G_recycle: 0.873 loss_D: 0.149
# loss_recurrent: 0.426 loss_D_A_fake: 0.141 loss_D_A_real: 0.000 loss_D_B_fake: 0.122 loss_D_B_real: 0.035
# Epoch[0](1020/2551) loss_PG: 7.676 loss_G_identity: 0.297 loss_G_GAN: 5.54 loss_G_recycle: 1.367 loss_D: 0.456
# loss_recurrent: 0.476 loss_D_A_fake: 0.060 loss_D_A_real: 0.001 loss_D_B_fake: 0.664 loss_D_B_real: 0.187
# Epoch[0](1040/2551) loss_PG: 13.620 loss_G_identity: 0.299 loss_G_GAN: 12.0 loss_G_recycle: 0.834 loss_D: 1.183
# loss_recurrent: 0.453 loss_D_A_fake: 0.092 loss_D_A_real: 1.739 loss_D_B_fake: 0.418 loss_D_B_real: 0.116
# Epoch[0](1060/2551) loss_PG: 8.631 loss_G_identity: 0.298 loss_G_GAN: 6.82 loss_G_recycle: 0.960 loss_D: 0.825
# loss_recurrent: 0.555 loss_D_A_fake: 0.715 loss_D_A_real: 0.368 loss_D_B_fake: 0.523 loss_D_B_real: 0.044
# Epoch[0](1080/2551) loss_PG: 23.457 loss_G_identity: 0.282 loss_G_GAN: 22.0 loss_G_recycle: 0.809 loss_D: 2.120
# loss_recurrent: 0.388 loss_D_A_fake: 0.011 loss_D_A_real: 2.072 loss_D_B_fake: 0.124 loss_D_B_real: 2.034
# Epoch[0](1100/2551) loss_PG: 4.519 loss_G_identity: 0.391 loss_G_GAN: 2.64 loss_G_recycle: 1.084 loss_D: 1.562
# loss_recurrent: 0.404 loss_D_A_fake: 1.837 loss_D_A_real: 0.034 loss_D_B_fake: 0.703 loss_D_B_real: 0.550
# Epoch[0](1120/2551) loss_PG: 13.829 loss_G_identity: 0.287 loss_G_GAN: 12.0 loss_G_recycle: 0.925 loss_D: 1.172
# loss_recurrent: 0.593 loss_D_A_fake: 0.534 loss_D_A_real: 0.000 loss_D_B_fake: 0.182 loss_D_B_real: 1.628
# Epoch[0](1140/2551) loss_PG: 10.234 loss_G_identity: 0.273 loss_G_GAN: 8.57 loss_G_recycle: 0.892 loss_D: 0.603
# loss_recurrent: 0.496 loss_D_A_fake: 0.146 loss_D_A_real: 0.003 loss_D_B_fake: 0.427 loss_D_B_real: 0.629
# Epoch[0](1160/2551) loss_PG: 12.095 loss_G_identity: 0.276 loss_G_GAN: 10.7 loss_G_recycle: 0.718 loss_D: 1.394
# loss_recurrent: 0.421 loss_D_A_fake: 0.036 loss_D_A_real: 1.078 loss_D_B_fake: 0.264 loss_D_B_real: 1.411
# Epoch[0](1180/2551) loss_PG: 8.824 loss_G_identity: 0.265 loss_G_GAN: 7.43 loss_G_recycle: 0.742 loss_D: 0.788
# loss_recurrent: 0.388 loss_D_A_fake: 0.230 loss_D_A_real: 0.037 loss_D_B_fake: 0.592 loss_D_B_real: 0.715
# Epoch[0](1200/2551) loss_PG: 4.923 loss_G_identity: 0.288 loss_G_GAN: 3.34 loss_G_recycle: 0.857 loss_D: 1.103
# loss_recurrent: 0.438 loss_D_A_fake: 0.974 loss_D_A_real: 0.006 loss_D_B_fake: 0.369 loss_D_B_real: 0.856
# Epoch[0](1220/2551) loss_PG: 14.211 loss_G_identity: 0.451 loss_G_GAN: 12.5 loss_G_recycle: 0.820 loss_D: 0.455
# loss_recurrent: 0.394 loss_D_A_fake: 0.241 loss_D_A_real: 0.243 loss_D_B_fake: 0.290 loss_D_B_real: 0.135
# Epoch[0](1240/2551) loss_PG: 14.779 loss_G_identity: 0.332 loss_G_GAN: 12.8 loss_G_recycle: 1.100 loss_D: 0.707
# loss_recurrent: 0.545 loss_D_A_fake: 0.762 loss_D_A_real: 0.325 loss_D_B_fake: 0.126 loss_D_B_real: 0.201
# Epoch[0](1260/2551) loss_PG: 11.102 loss_G_identity: 0.286 loss_G_GAN: 9.25 loss_G_recycle: 0.930 loss_D: 0.741
# loss_recurrent: 0.632 loss_D_A_fake: 0.108 loss_D_A_real: 0.022 loss_D_B_fake: 0.965 loss_D_B_real: 0.386
# Epoch[0](1280/2551) loss_PG: 8.092 loss_G_identity: 0.303 loss_G_GAN: 6.38 loss_G_recycle: 1.010 loss_D: 0.931
# loss_recurrent: 0.401 loss_D_A_fake: 0.589 loss_D_A_real: 0.692 loss_D_B_fake: 0.373 loss_D_B_real: 0.209
# Epoch[0](1300/2551) loss_PG: 9.502 loss_G_identity: 0.221 loss_G_GAN: 8.21 loss_G_recycle: 0.674 loss_D: 0.733
# loss_recurrent: 0.398 loss_D_A_fake: 0.358 loss_D_A_real: 0.003 loss_D_B_fake: 0.458 loss_D_B_real: 0.647
# Epoch[0](1320/2551) loss_PG: 13.527 loss_G_identity: 0.286 loss_G_GAN: 11.9 loss_G_recycle: 0.805 loss_D: 1.014
# loss_recurrent: 0.512 loss_D_A_fake: 0.349 loss_D_A_real: 0.000 loss_D_B_fake: 0.217 loss_D_B_real: 1.462
# Epoch[0](1340/2551) loss_PG: 11.400 loss_G_identity: 0.377 loss_G_GAN: 9.52 loss_G_recycle: 0.983 loss_D: 1.655
# loss_recurrent: 0.520 loss_D_A_fake: 0.530 loss_D_A_real: 2.249 loss_D_B_fake: 0.414 loss_D_B_real: 0.118
# Epoch[0](1360/2551) loss_PG: 10.985 loss_G_identity: 0.320 loss_G_GAN: 9.04 loss_G_recycle: 0.966 loss_D: 0.504
# loss_recurrent: 0.658 loss_D_A_fake: 0.720 loss_D_A_real: 0.088 loss_D_B_fake: 0.163 loss_D_B_real: 0.037
# Epoch[0](1380/2551) loss_PG: 8.500 loss_G_identity: 0.259 loss_G_GAN: 7.21 loss_G_recycle: 0.668 loss_D: 1.397
# loss_recurrent: 0.362 loss_D_A_fake: 0.757 loss_D_A_real: 0.474 loss_D_B_fake: 0.473 loss_D_B_real: 1.091
# Epoch[0](1400/2551) loss_PG: 9.063 loss_G_identity: 0.245 loss_G_GAN: 7.65 loss_G_recycle: 0.764 loss_D: 0.814
# loss_recurrent: 0.401 loss_D_A_fake: 0.295 loss_D_A_real: 0.002 loss_D_B_fake: 0.544 loss_D_B_real: 0.786
# Epoch[0](1420/2551) loss_PG: 6.204 loss_G_identity: 0.304 loss_G_GAN: 4.75 loss_G_recycle: 0.779 loss_D: 1.428
# loss_recurrent: 0.370 loss_D_A_fake: 1.371 loss_D_A_real: 0.273 loss_D_B_fake: 0.459 loss_D_B_real: 0.754
# Epoch[0](1440/2551) loss_PG: 19.437 loss_G_identity: 0.312 loss_G_GAN: 17.6 loss_G_recycle: 0.992 loss_D: 1.429
# loss_recurrent: 0.558 loss_D_A_fake: 0.520 loss_D_A_real: 0.002 loss_D_B_fake: 0.002 loss_D_B_real: 2.335
# Epoch[0](1460/2551) loss_PG: 12.654 loss_G_identity: 0.231 loss_G_GAN: 11.5 loss_G_recycle: 0.598 loss_D: 1.394
# loss_recurrent: 0.368 loss_D_A_fake: 0.631 loss_D_A_real: 0.704 loss_D_B_fake: 0.110 loss_D_B_real: 1.343
# Epoch[0](1480/2551) loss_PG: 19.363 loss_G_identity: 0.304 loss_G_GAN: 17.6 loss_G_recycle: 0.918 loss_D: 0.476
# loss_recurrent: 0.535 loss_D_A_fake: 0.079 loss_D_A_real: 0.113 loss_D_B_fake: 0.536 loss_D_B_real: 0.224
# Epoch[0](1500/2551) loss_PG: 13.374 loss_G_identity: 0.272 loss_G_GAN: 11.8 loss_G_recycle: 0.783 loss_D: 1.279
# loss_recurrent: 0.471 loss_D_A_fake: 0.741 loss_D_A_real: 0.003 loss_D_B_fake: 0.176 loss_D_B_real: 1.638
# Epoch[0](1520/2551) loss_PG: 15.233 loss_G_identity: 0.304 loss_G_GAN: 13.4 loss_G_recycle: 1.012 loss_D: 0.835
# loss_recurrent: 0.548 loss_D_A_fake: 0.080 loss_D_A_real: 0.636 loss_D_B_fake: 0.948 loss_D_B_real: 0.006
# Epoch[0](1540/2551) loss_PG: 16.550 loss_G_identity: 0.267 loss_G_GAN: 15.0 loss_G_recycle: 0.810 loss_D: 0.492
# loss_recurrent: 0.455 loss_D_A_fake: 0.142 loss_D_A_real: 0.095 loss_D_B_fake: 0.339 loss_D_B_real: 0.408
# Epoch[0](1560/2551) loss_PG: 15.649 loss_G_identity: 0.326 loss_G_GAN: 14.0 loss_G_recycle: 0.913 loss_D: 0.771
# loss_recurrent: 0.441 loss_D_A_fake: 0.730 loss_D_A_real: 0.204 loss_D_B_fake: 0.101 loss_D_B_real: 0.508
# Epoch[0](1580/2551) loss_PG: 10.302 loss_G_identity: 0.283 loss_G_GAN: 8.82 loss_G_recycle: 0.817 loss_D: 0.325
# loss_recurrent: 0.378 loss_D_A_fake: 0.308 loss_D_A_real: 0.009 loss_D_B_fake: 0.290 loss_D_B_real: 0.041
# Epoch[0](1600/2551) loss_PG: 15.288 loss_G_identity: 0.306 loss_G_GAN: 13.8 loss_G_recycle: 0.822 loss_D: 0.878
# loss_recurrent: 0.387 loss_D_A_fake: 0.321 loss_D_A_real: 0.029 loss_D_B_fake: 0.125 loss_D_B_real: 1.281
# Epoch[0](1620/2551) loss_PG: 19.464 loss_G_identity: 0.325 loss_G_GAN: 17.8 loss_G_recycle: 0.865 loss_D: 0.447
# loss_recurrent: 0.424 loss_D_A_fake: 0.072 loss_D_A_real: 0.636 loss_D_B_fake: 0.184 loss_D_B_real: 0.002
# Epoch[0](1640/2551) loss_PG: 14.640 loss_G_identity: 0.304 loss_G_GAN: 12.8 loss_G_recycle: 0.936 loss_D: 0.549
# loss_recurrent: 0.577 loss_D_A_fake: 0.027 loss_D_A_real: 0.011 loss_D_B_fake: 0.754 loss_D_B_real: 0.306
# Epoch[0](1660/2551) loss_PG: 8.965 loss_G_identity: 0.262 loss_G_GAN: 7.63 loss_G_recycle: 0.695 loss_D: 0.847
# loss_recurrent: 0.374 loss_D_A_fake: 0.197 loss_D_A_real: 0.036 loss_D_B_fake: 0.661 loss_D_B_real: 0.800
# Epoch[0](1680/2551) loss_PG: 20.021 loss_G_identity: 0.314 loss_G_GAN: 18.4 loss_G_recycle: 0.867 loss_D: 0.747
# loss_recurrent: 0.415 loss_D_A_fake: 0.041 loss_D_A_real: 1.021 loss_D_B_fake: 0.429 loss_D_B_real: 0.002
# Epoch[0](1700/2551) loss_PG: 19.046 loss_G_identity: 0.264 loss_G_GAN: 17.4 loss_G_recycle: 0.844 loss_D: 0.542
# loss_recurrent: 0.538 loss_D_A_fake: 0.044 loss_D_A_real: 0.070 loss_D_B_fake: 0.715 loss_D_B_real: 0.255
# Epoch[0](1720/2551) loss_PG: 16.874 loss_G_identity: 0.304 loss_G_GAN: 15.1 loss_G_recycle: 0.945 loss_D: 1.339
# loss_recurrent: 0.535 loss_D_A_fake: 0.080 loss_D_A_real: 1.558 loss_D_B_fake: 0.885 loss_D_B_real: 0.154
# Epoch[0](1740/2551) loss_PG: 16.937 loss_G_identity: 0.293 loss_G_GAN: 15.4 loss_G_recycle: 0.812 loss_D: 1.682
# loss_recurrent: 0.414 loss_D_A_fake: 0.077 loss_D_A_real: 1.776 loss_D_B_fake: 0.352 loss_D_B_real: 1.160
# Epoch[0](1760/2551) loss_PG: 19.683 loss_G_identity: 0.293 loss_G_GAN: 18.2 loss_G_recycle: 0.752 loss_D: 0.591
# loss_recurrent: 0.398 loss_D_A_fake: 0.004 loss_D_A_real: 0.434 loss_D_B_fake: 0.722 loss_D_B_real: 0.021
# Epoch[0](1780/2551) loss_PG: 15.121 loss_G_identity: 0.294 loss_G_GAN: 13.6 loss_G_recycle: 0.843 loss_D: 0.937
# loss_recurrent: 0.387 loss_D_A_fake: 0.048 loss_D_A_real: 0.164 loss_D_B_fake: 0.970 loss_D_B_real: 0.693
# Epoch[0](1800/2551) loss_PG: 6.892 loss_G_identity: 0.234 loss_G_GAN: 5.61 loss_G_recycle: 0.644 loss_D: 1.356
# loss_recurrent: 0.400 loss_D_A_fake: 0.647 loss_D_A_real: 0.002 loss_D_B_fake: 1.490 loss_D_B_real: 0.575
# Epoch[0](1820/2551) loss_PG: 13.720 loss_G_identity: 0.244 loss_G_GAN: 12.4 loss_G_recycle: 0.656 loss_D: 1.229
# loss_recurrent: 0.387 loss_D_A_fake: 0.276 loss_D_A_real: 0.642 loss_D_B_fake: 0.160 loss_D_B_real: 1.380
# Epoch[0](1840/2551) loss_PG: 22.607 loss_G_identity: 0.284 loss_G_GAN: 20.6 loss_G_recycle: 1.065 loss_D: 0.482
# loss_recurrent: 0.628 loss_D_A_fake: 0.027 loss_D_A_real: 0.352 loss_D_B_fake: 0.576 loss_D_B_real: 0.010
# Epoch[0](1860/2551) loss_PG: 15.213 loss_G_identity: 0.315 loss_G_GAN: 13.5 loss_G_recycle: 0.920 loss_D: 1.016
# loss_recurrent: 0.508 loss_D_A_fake: 0.297 loss_D_A_real: 1.473 loss_D_B_fake: 0.170 loss_D_B_real: 0.092
# Epoch[0](1880/2551) loss_PG: 8.579 loss_G_identity: 0.231 loss_G_GAN: 7.16 loss_G_recycle: 0.717 loss_D: 1.416
# loss_recurrent: 0.470 loss_D_A_fake: 1.451 loss_D_A_real: 0.009 loss_D_B_fake: 0.109 loss_D_B_real: 1.262
# Epoch[0](1900/2551) loss_PG: 11.696 loss_G_identity: 0.312 loss_G_GAN: 9.98 loss_G_recycle: 0.900 loss_D: 0.949
# loss_recurrent: 0.503 loss_D_A_fake: 0.415 loss_D_A_real: 0.987 loss_D_B_fake: 0.488 loss_D_B_real: 0.008
# Epoch[0](1920/2551) loss_PG: 12.585 loss_G_identity: 0.277 loss_G_GAN: 11.2 loss_G_recycle: 0.746 loss_D: 0.850
# loss_recurrent: 0.383 loss_D_A_fake: 0.190 loss_D_A_real: 1.189 loss_D_B_fake: 0.315 loss_D_B_real: 0.006
# Epoch[0](1940/2551) loss_PG: 6.359 loss_G_identity: 0.381 loss_G_GAN: 4.47 loss_G_recycle: 1.053 loss_D: 0.954
# loss_recurrent: 0.458 loss_D_A_fake: 0.434 loss_D_A_real: 0.078 loss_D_B_fake: 1.112 loss_D_B_real: 0.284
# Epoch[0](1960/2551) loss_PG: 18.422 loss_G_identity: 0.301 loss_G_GAN: 16.8 loss_G_recycle: 0.884 loss_D: 0.945
# loss_recurrent: 0.484 loss_D_A_fake: 0.124 loss_D_A_real: 1.406 loss_D_B_fake: 0.130 loss_D_B_real: 0.230
# Epoch[0](1980/2551) loss_PG: 15.300 loss_G_identity: 0.242 loss_G_GAN: 14.0 loss_G_recycle: 0.679 loss_D: 0.874
# loss_recurrent: 0.426 loss_D_A_fake: 0.122 loss_D_A_real: 0.002 loss_D_B_fake: 0.270 loss_D_B_real: 1.355
# Epoch[0](2000/2551) loss_PG: 7.888 loss_G_identity: 0.271 loss_G_GAN: 6.46 loss_G_recycle: 0.809 loss_D: 0.645
# loss_recurrent: 0.350 loss_D_A_fake: 0.071 loss_D_A_real: 0.059 loss_D_B_fake: 0.528 loss_D_B_real: 0.633
# Epoch[0](2020/2551) loss_PG: 10.903 loss_G_identity: 0.292 loss_G_GAN: 9.32 loss_G_recycle: 0.882 loss_D: 0.682
# loss_recurrent: 0.403 loss_D_A_fake: 0.196 loss_D_A_real: 0.001 loss_D_B_fake: 0.272 loss_D_B_real: 0.895
# Epoch[0](2040/2551) loss_PG: 12.298 loss_G_identity: 0.267 loss_G_GAN: 10.9 loss_G_recycle: 0.689 loss_D: 0.502
# loss_recurrent: 0.404 loss_D_A_fake: 0.076 loss_D_A_real: 0.066 loss_D_B_fake: 0.487 loss_D_B_real: 0.374
# Epoch[0](2060/2551) loss_PG: 20.744 loss_G_identity: 0.359 loss_G_GAN: 18.9 loss_G_recycle: 0.908 loss_D: 0.598
# loss_recurrent: 0.549 loss_D_A_fake: 0.091 loss_D_A_real: 0.313 loss_D_B_fake: 0.710 loss_D_B_real: 0.083
# Epoch[0](2080/2551) loss_PG: 8.546 loss_G_identity: 0.317 loss_G_GAN: 6.86 loss_G_recycle: 0.896 loss_D: 1.893
# loss_recurrent: 0.477 loss_D_A_fake: 0.081 loss_D_A_real: 1.428 loss_D_B_fake: 1.999 loss_D_B_real: 0.278
# Epoch[0](2100/2551) loss_PG: 11.661 loss_G_identity: 0.290 loss_G_GAN: 10.1 loss_G_recycle: 0.875 loss_D: 0.450
# loss_recurrent: 0.374 loss_D_A_fake: 0.378 loss_D_A_real: 0.163 loss_D_B_fake: 0.225 loss_D_B_real: 0.133
# Epoch[0](2120/2551) loss_PG: 13.752 loss_G_identity: 0.283 loss_G_GAN: 12.3 loss_G_recycle: 0.774 loss_D: 1.068
# loss_recurrent: 0.406 loss_D_A_fake: 0.466 loss_D_A_real: 0.004 loss_D_B_fake: 0.226 loss_D_B_real: 1.439
# Epoch[0](2140/2551) loss_PG: 15.556 loss_G_identity: 0.329 loss_G_GAN: 13.8 loss_G_recycle: 0.933 loss_D: 0.883
# loss_recurrent: 0.490 loss_D_A_fake: 0.318 loss_D_A_real: 1.328 loss_D_B_fake: 0.119 loss_D_B_real: 0.002
# Epoch[0](2160/2551) loss_PG: 12.341 loss_G_identity: 0.269 loss_G_GAN: 10.6 loss_G_recycle: 0.897 loss_D: 1.127
# loss_recurrent: 0.601 loss_D_A_fake: 0.700 loss_D_A_real: 0.022 loss_D_B_fake: 0.153 loss_D_B_real: 1.379
# Epoch[0](2180/2551) loss_PG: 15.307 loss_G_identity: 0.311 loss_G_GAN: 13.4 loss_G_recycle: 0.948 loss_D: 0.813
# loss_recurrent: 0.634 loss_D_A_fake: 0.443 loss_D_A_real: 1.055 loss_D_B_fake: 0.121 loss_D_B_real: 0.007
# Epoch[0](2200/2551) loss_PG: 7.505 loss_G_identity: 0.317 loss_G_GAN: 5.8 loss_G_recycle: 0.875 loss_D: 0.834
# loss_recurrent: 0.508 loss_D_A_fake: 0.306 loss_D_A_real: 0.017 loss_D_B_fake: 0.966 loss_D_B_real: 0.380
# Epoch[0](2220/2551) loss_PG: 15.040 loss_G_identity: 0.289 loss_G_GAN: 13.2 loss_G_recycle: 0.936 loss_D: 0.534
# loss_recurrent: 0.620 loss_D_A_fake: 0.336 loss_D_A_real: 0.178 loss_D_B_fake: 0.318 loss_D_B_real: 0.237
# Epoch[0](2240/2551) loss_PG: 15.456 loss_G_identity: 0.313 loss_G_GAN: 13.5 loss_G_recycle: 0.960 loss_D: 0.447
# loss_recurrent: 0.649 loss_D_A_fake: 0.262 loss_D_A_real: 0.234 loss_D_B_fake: 0.304 loss_D_B_real: 0.095
# Epoch[0](2260/2551) loss_PG: 14.048 loss_G_identity: 0.299 loss_G_GAN: 12.4 loss_G_recycle: 0.942 loss_D: 0.481
# loss_recurrent: 0.403 loss_D_A_fake: 0.001 loss_D_A_real: 0.002 loss_D_B_fake: 0.232 loss_D_B_real: 0.727
# Epoch[0](2280/2551) loss_PG: 14.447 loss_G_identity: 0.258 loss_G_GAN: 13.1 loss_G_recycle: 0.682 loss_D: 1.443
# loss_recurrent: 0.455 loss_D_A_fake: 0.152 loss_D_A_real: 1.507 loss_D_B_fake: 0.761 loss_D_B_real: 0.466
# Epoch[0](2300/2551) loss_PG: 12.516 loss_G_identity: 0.295 loss_G_GAN: 10.9 loss_G_recycle: 0.871 loss_D: 0.782
# loss_recurrent: 0.429 loss_D_A_fake: 0.333 loss_D_A_real: 0.000 loss_D_B_fake: 0.554 loss_D_B_real: 0.677
# Epoch[0](2320/2551) loss_PG: 17.132 loss_G_identity: 0.276 loss_G_GAN: 15.6 loss_G_recycle: 0.782 loss_D: 1.401
# loss_recurrent: 0.465 loss_D_A_fake: 0.507 loss_D_A_real: 0.002 loss_D_B_fake: 0.037 loss_D_B_real: 2.257
# Epoch[0](2340/2551) loss_PG: 18.450 loss_G_identity: 0.258 loss_G_GAN: 16.9 loss_G_recycle: 0.815 loss_D: 1.264
# loss_recurrent: 0.478 loss_D_A_fake: 0.108 loss_D_A_real: 2.152 loss_D_B_fake: 0.263 loss_D_B_real: 0.005
# Epoch[0](2360/2551) loss_PG: 12.381 loss_G_identity: 0.238 loss_G_GAN: 11.0 loss_G_recycle: 0.685 loss_D: 1.403
# loss_recurrent: 0.491 loss_D_A_fake: 0.179 loss_D_A_real: 1.170 loss_D_B_fake: 1.071 loss_D_B_real: 0.386
# Epoch[0](2380/2551) loss_PG: 19.868 loss_G_identity: 0.321 loss_G_GAN: 18.2 loss_G_recycle: 0.991 loss_D: 0.648
# loss_recurrent: 0.366 loss_D_A_fake: 0.032 loss_D_A_real: 0.164 loss_D_B_fake: 1.000 loss_D_B_real: 0.099
# Epoch[0](2400/2551) loss_PG: 17.074 loss_G_identity: 0.286 loss_G_GAN: 15.5 loss_G_recycle: 0.848 loss_D: 0.457
# loss_recurrent: 0.394 loss_D_A_fake: 0.054 loss_D_A_real: 0.079 loss_D_B_fake: 0.780 loss_D_B_real: 0.000
# Epoch[0](2420/2551) loss_PG: 11.059 loss_G_identity: 0.299 loss_G_GAN: 9.59 loss_G_recycle: 0.776 loss_D: 0.701
# loss_recurrent: 0.392 loss_D_A_fake: 0.207 loss_D_A_real: 0.062 loss_D_B_fake: 0.533 loss_D_B_real: 0.600
# Epoch[0](2440/2551) loss_PG: 12.066 loss_G_identity: 0.282 loss_G_GAN: 10.5 loss_G_recycle: 0.828 loss_D: 0.913
# loss_recurrent: 0.482 loss_D_A_fake: 0.230 loss_D_A_real: 0.279 loss_D_B_fake: 0.469 loss_D_B_real: 0.848
# Epoch[0](2460/2551) loss_PG: 12.184 loss_G_identity: 0.245 loss_G_GAN: 10.8 loss_G_recycle: 0.727 loss_D: 0.719
# loss_recurrent: 0.403 loss_D_A_fake: 0.254 loss_D_A_real: 0.087 loss_D_B_fake: 0.435 loss_D_B_real: 0.661
# Epoch[0](2480/2551) loss_PG: 13.265 loss_G_identity: 0.317 loss_G_GAN: 11.6 loss_G_recycle: 0.900 loss_D: 1.289
# loss_recurrent: 0.472 loss_D_A_fake: 0.107 loss_D_A_real: 2.148 loss_D_B_fake: 0.314 loss_D_B_real: 0.008
# Epoch[0](2500/2551) loss_PG: 17.106 loss_G_identity: 0.315 loss_G_GAN: 15.6 loss_G_recycle: 0.779 loss_D: 0.179
# loss_recurrent: 0.407 loss_D_A_fake: 0.170 loss_D_A_real: 0.012 loss_D_B_fake: 0.130 loss_D_B_real: 0.046
# Epoch[0](2520/2551) loss_PG: 9.830 loss_G_identity: 0.332 loss_G_GAN: 8.04 loss_G_recycle: 0.916 loss_D: 0.831
# loss_recurrent: 0.541 loss_D_A_fake: 0.660 loss_D_A_real: 0.700 loss_D_B_fake: 0.265 loss_D_B_real: 0.038
# Epoch[0](2540/2551) loss_PG: 6.952 loss_G_identity: 0.305 loss_G_GAN: 5.06 loss_G_recycle: 0.929 loss_D: 1.560
# loss_recurrent: 0.663 loss_D_A_fake: 0.677 loss_D_A_real: 1.327 loss_D_B_fake: 1.094 loss_D_B_real: 0.022
# Epoch[1](0/2551) loss_PG: 14.571 loss_G_identity: 0.280 loss_G_GAN: 12.8 loss_G_recycle: 0.893 loss_D: 1.218
# loss_recurrent: 0.585 loss_D_A_fake: 0.135 loss_D_A_real: 1.749 loss_D_B_fake: 0.506 loss_D_B_real: 0.045
# Epoch[1](20/2551) loss_PG: 7.742 loss_G_identity: 0.302 loss_G_GAN: 5.92 loss_G_recycle: 1.021 loss_D: 0.582
# loss_recurrent: 0.503 loss_D_A_fake: 0.623 loss_D_A_real: 0.000 loss_D_B_fake: 0.533 loss_D_B_real: 0.007
# Epoch[1](40/2551) loss_PG: 23.590 loss_G_identity: 0.302 loss_G_GAN: 21.9 loss_G_recycle: 0.884 loss_D: 0.910
# loss_recurrent: 0.538 loss_D_A_fake: 0.017 loss_D_A_real: 1.522 loss_D_B_fake: 0.228 loss_D_B_real: 0.052
# Epoch[1](60/2551) loss_PG: 17.473 loss_G_identity: 0.252 loss_G_GAN: 16.0 loss_G_recycle: 0.770 loss_D: 1.780
# loss_recurrent: 0.414 loss_D_A_fake: 0.063 loss_D_A_real: 2.102 loss_D_B_fake: 0.615 loss_D_B_real: 0.780
# Epoch[1](80/2551) loss_PG: 10.323 loss_G_identity: 0.222 loss_G_GAN: 9.12 loss_G_recycle: 0.610 loss_D: 0.814
# loss_recurrent: 0.368 loss_D_A_fake: 0.368 loss_D_A_real: 0.108 loss_D_B_fake: 0.108 loss_D_B_real: 1.044
# Epoch[1](100/2551) loss_PG: 11.116 loss_G_identity: 0.266 loss_G_GAN: 9.73 loss_G_recycle: 0.746 loss_D: 0.455
# loss_recurrent: 0.376 loss_D_A_fake: 0.151 loss_D_A_real: 0.039 loss_D_B_fake: 0.603 loss_D_B_real: 0.117
# Epoch[1](120/2551) loss_PG: 7.957 loss_G_identity: 0.253 loss_G_GAN: 6.58 loss_G_recycle: 0.701 loss_D: 0.928
# loss_recurrent: 0.422 loss_D_A_fake: 1.058 loss_D_A_real: 0.368 loss_D_B_fake: 0.398 loss_D_B_real: 0.032
# Epoch[1](140/2551) loss_PG: 7.779 loss_G_identity: 0.301 loss_G_GAN: 6.08 loss_G_recycle: 0.891 loss_D: 1.238
# loss_recurrent: 0.505 loss_D_A_fake: 0.654 loss_D_A_real: 1.054 loss_D_B_fake: 0.737 loss_D_B_real: 0.031
# Epoch[1](160/2551) loss_PG: 19.996 loss_G_identity: 0.266 loss_G_GAN: 18.5 loss_G_recycle: 0.768 loss_D: 1.415
# loss_recurrent: 0.448 loss_D_A_fake: 0.264 loss_D_A_real: 0.010 loss_D_B_fake: 0.153 loss_D_B_real: 2.404
# Epoch[1](180/2551) loss_PG: 8.665 loss_G_identity: 0.218 loss_G_GAN: 7.49 loss_G_recycle: 0.572 loss_D: 1.363
# loss_recurrent: 0.384 loss_D_A_fake: 0.511 loss_D_A_real: 1.020 loss_D_B_fake: 0.594 loss_D_B_real: 0.602
# Epoch[1](200/2551) loss_PG: 12.983 loss_G_identity: 0.245 loss_G_GAN: 11.6 loss_G_recycle: 0.701 loss_D: 1.034
# loss_recurrent: 0.447 loss_D_A_fake: 0.199 loss_D_A_real: 0.743 loss_D_B_fake: 0.770 loss_D_B_real: 0.356
# Epoch[1](220/2551) loss_PG: 11.786 loss_G_identity: 0.235 loss_G_GAN: 10.5 loss_G_recycle: 0.625 loss_D: 1.474
# loss_recurrent: 0.385 loss_D_A_fake: 0.609 loss_D_A_real: 0.594 loss_D_B_fake: 0.196 loss_D_B_real: 1.548
# Epoch[1](240/2551) loss_PG: 8.396 loss_G_identity: 0.288 loss_G_GAN: 6.99 loss_G_recycle: 0.739 loss_D: 1.187
# loss_recurrent: 0.383 loss_D_A_fake: 0.411 loss_D_A_real: 0.003 loss_D_B_fake: 1.633 loss_D_B_real: 0.326
# Epoch[1](260/2551) loss_PG: 15.924 loss_G_identity: 0.271 loss_G_GAN: 14.5 loss_G_recycle: 0.781 loss_D: 1.180
# loss_recurrent: 0.385 loss_D_A_fake: 0.215 loss_D_A_real: 0.027 loss_D_B_fake: 0.181 loss_D_B_real: 1.939
# Epoch[1](280/2551) loss_PG: 11.830 loss_G_identity: 0.283 loss_G_GAN: 9.88 loss_G_recycle: 0.936 loss_D: 0.432
# loss_recurrent: 0.735 loss_D_A_fake: 0.232 loss_D_A_real: 0.081 loss_D_B_fake: 0.539 loss_D_B_real: 0.012
# Epoch[1](300/2551) loss_PG: 5.667 loss_G_identity: 0.284 loss_G_GAN: 3.86 loss_G_recycle: 0.902 loss_D: 1.776
# loss_recurrent: 0.621 loss_D_A_fake: 0.876 loss_D_A_real: 0.252 loss_D_B_fake: 2.051 loss_D_B_real: 0.371
# Epoch[1](320/2551) loss_PG: 18.642 loss_G_identity: 0.310 loss_G_GAN: 16.8 loss_G_recycle: 0.888 loss_D: 1.699
# loss_recurrent: 0.625 loss_D_A_fake: 0.002 loss_D_A_real: 2.783 loss_D_B_fake: 0.452 loss_D_B_real: 0.161
# Epoch[1](340/2551) loss_PG: 6.894 loss_G_identity: 0.247 loss_G_GAN: 5.43 loss_G_recycle: 0.746 loss_D: 1.460
# loss_recurrent: 0.468 loss_D_A_fake: 0.767 loss_D_A_real: 0.617 loss_D_B_fake: 0.967 loss_D_B_real: 0.568
# Epoch[1](360/2551) loss_PG: 13.608 loss_G_identity: 0.288 loss_G_GAN: 12.0 loss_G_recycle: 0.859 loss_D: 0.759
# loss_recurrent: 0.483 loss_D_A_fake: 0.223 loss_D_A_real: 0.017 loss_D_B_fake: 0.552 loss_D_B_real: 0.725
# Epoch[1](380/2551) loss_PG: 14.995 loss_G_identity: 0.285 loss_G_GAN: 13.4 loss_G_recycle: 0.858 loss_D: 1.091
# loss_recurrent: 0.497 loss_D_A_fake: 0.172 loss_D_A_real: 1.525 loss_D_B_fake: 0.443 loss_D_B_real: 0.042
# Epoch[1](400/2551) loss_PG: 12.148 loss_G_identity: 0.259 loss_G_GAN: 10.8 loss_G_recycle: 0.677 loss_D: 1.790
# loss_recurrent: 0.435 loss_D_A_fake: 0.344 loss_D_A_real: 1.744 loss_D_B_fake: 0.200 loss_D_B_real: 1.292
# Epoch[1](420/2551) loss_PG: 9.664 loss_G_identity: 0.225 loss_G_GAN: 8.42 loss_G_recycle: 0.624 loss_D: 1.234
# loss_recurrent: 0.397 loss_D_A_fake: 0.395 loss_D_A_real: 0.605 loss_D_B_fake: 0.204 loss_D_B_real: 1.264
# Epoch[1](440/2551) loss_PG: 15.105 loss_G_identity: 0.274 loss_G_GAN: 13.6 loss_G_recycle: 0.808 loss_D: 0.898
# loss_recurrent: 0.423 loss_D_A_fake: 0.280 loss_D_A_real: 0.000 loss_D_B_fake: 0.167 loss_D_B_real: 1.349
# Epoch[1](460/2551) loss_PG: 12.377 loss_G_identity: 0.261 loss_G_GAN: 11.1 loss_G_recycle: 0.670 loss_D: 0.873
# loss_recurrent: 0.365 loss_D_A_fake: 0.658 loss_D_A_real: 0.872 loss_D_B_fake: 0.151 loss_D_B_real: 0.064
# Epoch[1](480/2551) loss_PG: 14.190 loss_G_identity: 0.280 loss_G_GAN: 12.4 loss_G_recycle: 0.914 loss_D: 0.741
# loss_recurrent: 0.592 loss_D_A_fake: 0.015 loss_D_A_real: 0.057 loss_D_B_fake: 0.913 loss_D_B_real: 0.498
# Epoch[1](500/2551) loss_PG: 17.896 loss_G_identity: 0.242 loss_G_GAN: 16.5 loss_G_recycle: 0.723 loss_D: 1.296
# loss_recurrent: 0.476 loss_D_A_fake: 0.072 loss_D_A_real: 1.146 loss_D_B_fake: 0.332 loss_D_B_real: 1.043
# Epoch[1](520/2551) loss_PG: 14.961 loss_G_identity: 0.299 loss_G_GAN: 13.2 loss_G_recycle: 0.909 loss_D: 0.279
# loss_recurrent: 0.565 loss_D_A_fake: 0.277 loss_D_A_real: 0.008 loss_D_B_fake: 0.135 loss_D_B_real: 0.138
# Epoch[1](540/2551) loss_PG: 8.968 loss_G_identity: 0.313 loss_G_GAN: 7.29 loss_G_recycle: 0.846 loss_D: 1.170
# loss_recurrent: 0.521 loss_D_A_fake: 0.775 loss_D_A_real: 0.594 loss_D_B_fake: 0.934 loss_D_B_real: 0.037
# Epoch[1](560/2551) loss_PG: 20.350 loss_G_identity: 0.277 loss_G_GAN: 18.9 loss_G_recycle: 0.822 loss_D: 0.722
# loss_recurrent: 0.368 loss_D_A_fake: 0.007 loss_D_A_real: 0.294 loss_D_B_fake: 1.134 loss_D_B_real: 0.009
# Epoch[1](580/2551) loss_PG: 17.190 loss_G_identity: 0.285 loss_G_GAN: 15.4 loss_G_recycle: 0.955 loss_D: 1.212
# loss_recurrent: 0.537 loss_D_A_fake: 0.359 loss_D_A_real: 0.013 loss_D_B_fake: 0.130 loss_D_B_real: 1.922
# Epoch[1](600/2551) loss_PG: 7.648 loss_G_identity: 0.230 loss_G_GAN: 6.28 loss_G_recycle: 0.672 loss_D: 1.689
# loss_recurrent: 0.470 loss_D_A_fake: 1.779 loss_D_A_real: 0.184 loss_D_B_fake: 0.430 loss_D_B_real: 0.984
# Epoch[1](620/2551) loss_PG: 14.970 loss_G_identity: 0.330 loss_G_GAN: 13.2 loss_G_recycle: 0.937 loss_D: 0.236
# loss_recurrent: 0.538 loss_D_A_fake: 0.080 loss_D_A_real: 0.000 loss_D_B_fake: 0.368 loss_D_B_real: 0.023
# Epoch[1](640/2551) loss_PG: 11.716 loss_G_identity: 0.229 loss_G_GAN: 10.5 loss_G_recycle: 0.635 loss_D: 1.584
# loss_recurrent: 0.396 loss_D_A_fake: 0.164 loss_D_A_real: 1.332 loss_D_B_fake: 0.899 loss_D_B_real: 0.772
# Epoch[1](660/2551) loss_PG: 16.678 loss_G_identity: 0.299 loss_G_GAN: 15.0 loss_G_recycle: 0.865 loss_D: 1.702
# loss_recurrent: 0.544 loss_D_A_fake: 0.032 loss_D_A_real: 2.591 loss_D_B_fake: 0.731 loss_D_B_real: 0.050
# Epoch[1](680/2551) loss_PG: 14.193 loss_G_identity: 0.254 loss_G_GAN: 12.8 loss_G_recycle: 0.712 loss_D: 1.351
# loss_recurrent: 0.389 loss_D_A_fake: 0.158 loss_D_A_real: 1.829 loss_D_B_fake: 0.715 loss_D_B_real: 0.000
# Epoch[1](700/2551) loss_PG: 11.935 loss_G_identity: 0.310 loss_G_GAN: 10.2 loss_G_recycle: 0.897 loss_D: 0.602
# loss_recurrent: 0.492 loss_D_A_fake: 0.170 loss_D_A_real: 0.000 loss_D_B_fake: 0.464 loss_D_B_real: 0.569
# Epoch[1](720/2551) loss_PG: 9.574 loss_G_identity: 0.244 loss_G_GAN: 8.11 loss_G_recycle: 0.784 loss_D: 0.883
# loss_recurrent: 0.435 loss_D_A_fake: 0.724 loss_D_A_real: 0.001 loss_D_B_fake: 0.200 loss_D_B_real: 0.840
# Epoch[1](740/2551) loss_PG: 15.686 loss_G_identity: 0.299 loss_G_GAN: 13.9 loss_G_recycle: 0.919 loss_D: 0.246
# loss_recurrent: 0.572 loss_D_A_fake: 0.335 loss_D_A_real: 0.017 loss_D_B_fake: 0.136 loss_D_B_real: 0.005
# Epoch[1](760/2551) loss_PG: 17.406 loss_G_identity: 0.272 loss_G_GAN: 15.8 loss_G_recycle: 0.835 loss_D: 1.239
# loss_recurrent: 0.456 loss_D_A_fake: 0.055 loss_D_A_real: 2.262 loss_D_B_fake: 0.127 loss_D_B_real: 0.035
# Epoch[1](780/2551) loss_PG: 14.470 loss_G_identity: 0.224 loss_G_GAN: 13.3 loss_G_recycle: 0.602 loss_D: 1.731
# loss_recurrent: 0.381 loss_D_A_fake: 0.150 loss_D_A_real: 1.925 loss_D_B_fake: 0.471 loss_D_B_real: 0.916
# Epoch[1](800/2551) loss_PG: 17.813 loss_G_identity: 0.307 loss_G_GAN: 16.0 loss_G_recycle: 0.996 loss_D: 0.801
# loss_recurrent: 0.542 loss_D_A_fake: 0.127 loss_D_A_real: 0.009 loss_D_B_fake: 0.541 loss_D_B_real: 0.924
# Epoch[1](820/2551) loss_PG: 15.636 loss_G_identity: 0.313 loss_G_GAN: 13.9 loss_G_recycle: 0.933 loss_D: 0.325
# loss_recurrent: 0.507 loss_D_A_fake: 0.106 loss_D_A_real: 0.146 loss_D_B_fake: 0.375 loss_D_B_real: 0.024
# Epoch[1](840/2551) loss_PG: 16.365 loss_G_identity: 0.246 loss_G_GAN: 15.1 loss_G_recycle: 0.663 loss_D: 1.561
# loss_recurrent: 0.378 loss_D_A_fake: 0.329 loss_D_A_real: 1.170 loss_D_B_fake: 0.192 loss_D_B_real: 1.431
# Epoch[1](860/2551) loss_PG: 7.650 loss_G_identity: 0.249 loss_G_GAN: 6.28 loss_G_recycle: 0.730 loss_D: 1.262
# loss_recurrent: 0.391 loss_D_A_fake: 0.660 loss_D_A_real: 0.706 loss_D_B_fake: 0.354 loss_D_B_real: 0.804
# Epoch[1](880/2551) loss_PG: 10.128 loss_G_identity: 0.235 loss_G_GAN: 8.62 loss_G_recycle: 0.796 loss_D: 1.110
# loss_recurrent: 0.480 loss_D_A_fake: 0.449 loss_D_A_real: 0.351 loss_D_B_fake: 0.937 loss_D_B_real: 0.483
# Epoch[1](900/2551) loss_PG: 14.855 loss_G_identity: 0.302 loss_G_GAN: 13.2 loss_G_recycle: 0.978 loss_D: 0.622
# loss_recurrent: 0.396 loss_D_A_fake: 0.210 loss_D_A_real: 0.000 loss_D_B_fake: 0.410 loss_D_B_real: 0.624
# Epoch[1](920/2551) loss_PG: 10.862 loss_G_identity: 0.285 loss_G_GAN: 9.35 loss_G_recycle: 0.806 loss_D: 0.724
# loss_recurrent: 0.421 loss_D_A_fake: 0.183 loss_D_A_real: 0.039 loss_D_B_fake: 0.374 loss_D_B_real: 0.852
# Epoch[1](940/2551) loss_PG: 14.693 loss_G_identity: 0.289 loss_G_GAN: 12.9 loss_G_recycle: 0.891 loss_D: 0.360
# loss_recurrent: 0.566 loss_D_A_fake: 0.173 loss_D_A_real: 0.002 loss_D_B_fake: 0.529 loss_D_B_real: 0.015
# Epoch[1](960/2551) loss_PG: 8.674 loss_G_identity: 0.234 loss_G_GAN: 7.37 loss_G_recycle: 0.664 loss_D: 1.917
# loss_recurrent: 0.410 loss_D_A_fake: 0.394 loss_D_A_real: 1.516 loss_D_B_fake: 1.354 loss_D_B_real: 0.570
# Epoch[1](980/2551) loss_PG: 15.951 loss_G_identity: 0.262 loss_G_GAN: 14.3 loss_G_recycle: 0.830 loss_D: 0.645
# loss_recurrent: 0.584 loss_D_A_fake: 0.234 loss_D_A_real: 0.233 loss_D_B_fake: 0.808 loss_D_B_real: 0.016
# Epoch[1](1000/2551) loss_PG: 6.735 loss_G_identity: 0.396 loss_G_GAN: 5.0 loss_G_recycle: 0.947 loss_D: 0.999
# loss_recurrent: 0.392 loss_D_A_fake: 0.962 loss_D_A_real: 0.652 loss_D_B_fake: 0.334 loss_D_B_real: 0.050
# Epoch[1](1020/2551) loss_PG: 16.122 loss_G_identity: 0.294 loss_G_GAN: 14.4 loss_G_recycle: 0.837 loss_D: 0.246
# loss_recurrent: 0.541 loss_D_A_fake: 0.231 loss_D_A_real: 0.033 loss_D_B_fake: 0.097 loss_D_B_real: 0.131
# Epoch[1](1040/2551) loss_PG: 8.889 loss_G_identity: 0.314 loss_G_GAN: 6.92 loss_G_recycle: 1.040 loss_D: 1.966
# loss_recurrent: 0.618 loss_D_A_fake: 0.094 loss_D_A_real: 1.501 loss_D_B_fake: 1.804 loss_D_B_real: 0.531
# Epoch[1](1060/2551) loss_PG: 16.351 loss_G_identity: 0.230 loss_G_GAN: 15.0 loss_G_recycle: 0.648 loss_D: 2.222
# loss_recurrent: 0.448 loss_D_A_fake: 0.061 loss_D_A_real: 2.326 loss_D_B_fake: 0.646 loss_D_B_real: 1.410
# Epoch[1](1080/2551) loss_PG: 19.223 loss_G_identity: 0.296 loss_G_GAN: 17.6 loss_G_recycle: 0.875 loss_D: 0.586
# loss_recurrent: 0.462 loss_D_A_fake: 0.084 loss_D_A_real: 0.234 loss_D_B_fake: 0.840 loss_D_B_real: 0.013
# Epoch[1](1100/2551) loss_PG: 11.384 loss_G_identity: 0.278 loss_G_GAN: 9.92 loss_G_recycle: 0.770 loss_D: 0.658
# loss_recurrent: 0.418 loss_D_A_fake: 0.363 loss_D_A_real: 0.753 loss_D_B_fake: 0.200 loss_D_B_real: 0.000
# Epoch[1](1120/2551) loss_PG: 20.822 loss_G_identity: 0.270 loss_G_GAN: 19.1 loss_G_recycle: 0.848 loss_D: 0.129
# loss_recurrent: 0.564 loss_D_A_fake: 0.170 loss_D_A_real: 0.003 loss_D_B_fake: 0.024 loss_D_B_real: 0.061
# Epoch[1](1140/2551) loss_PG: 10.950 loss_G_identity: 0.233 loss_G_GAN: 9.57 loss_G_recycle: 0.705 loss_D: 0.656
# loss_recurrent: 0.443 loss_D_A_fake: 0.048 loss_D_A_real: 0.003 loss_D_B_fake: 0.189 loss_D_B_real: 1.073
# Epoch[1](1160/2551) loss_PG: 8.793 loss_G_identity: 0.300 loss_G_GAN: 7.22 loss_G_recycle: 0.857 loss_D: 0.711
# loss_recurrent: 0.416 loss_D_A_fake: 0.717 loss_D_A_real: 0.404 loss_D_B_fake: 0.282 loss_D_B_real: 0.020
# Epoch[1](1180/2551) loss_PG: 16.483 loss_G_identity: 0.309 loss_G_GAN: 15.0 loss_G_recycle: 0.774 loss_D: 0.343
# loss_recurrent: 0.407 loss_D_A_fake: 0.055 loss_D_A_real: 0.227 loss_D_B_fake: 0.393 loss_D_B_real: 0.011
# Epoch[1](1200/2551) loss_PG: 13.060 loss_G_identity: 0.335 loss_G_GAN: 11.3 loss_G_recycle: 0.898 loss_D: 1.207
# loss_recurrent: 0.565 loss_D_A_fake: 0.588 loss_D_A_real: 0.000 loss_D_B_fake: 0.275 loss_D_B_real: 1.551
# Epoch[1](1220/2551) loss_PG: 12.264 loss_G_identity: 0.345 loss_G_GAN: 10.4 loss_G_recycle: 1.059 loss_D: 0.520
# loss_recurrent: 0.475 loss_D_A_fake: 0.132 loss_D_A_real: 0.072 loss_D_B_fake: 0.833 loss_D_B_real: 0.002
# Epoch[1](1240/2551) loss_PG: 10.518 loss_G_identity: 0.272 loss_G_GAN: 8.76 loss_G_recycle: 0.894 loss_D: 0.608
# loss_recurrent: 0.592 loss_D_A_fake: 0.178 loss_D_A_real: 0.273 loss_D_B_fake: 0.752 loss_D_B_real: 0.013
# Epoch[1](1260/2551) loss_PG: 13.061 loss_G_identity: 0.293 loss_G_GAN: 11.6 loss_G_recycle: 0.805 loss_D: 0.907
# loss_recurrent: 0.403 loss_D_A_fake: 0.173 loss_D_A_real: 1.130 loss_D_B_fake: 0.506 loss_D_B_real: 0.005
# Epoch[1](1280/2551) loss_PG: 16.845 loss_G_identity: 0.277 loss_G_GAN: 15.5 loss_G_recycle: 0.721 loss_D: 1.228
# loss_recurrent: 0.356 loss_D_A_fake: 0.413 loss_D_A_real: 0.012 loss_D_B_fake: 0.101 loss_D_B_real: 1.931
# Epoch[1](1300/2551) loss_PG: 10.237 loss_G_identity: 0.248 loss_G_GAN: 8.56 loss_G_recycle: 1.012 loss_D: 1.224
# loss_recurrent: 0.416 loss_D_A_fake: 0.672 loss_D_A_real: 0.007 loss_D_B_fake: 0.418 loss_D_B_real: 1.351
# Epoch[1](1320/2551) loss_PG: 16.921 loss_G_identity: 0.248 loss_G_GAN: 15.6 loss_G_recycle: 0.695 loss_D: 0.887
# loss_recurrent: 0.379 loss_D_A_fake: 0.149 loss_D_A_real: 1.511 loss_D_B_fake: 0.105 loss_D_B_real: 0.008
# Epoch[1](1340/2551) loss_PG: 18.927 loss_G_identity: 0.316 loss_G_GAN: 17.0 loss_G_recycle: 1.060 loss_D: 0.305
# loss_recurrent: 0.570 loss_D_A_fake: 0.496 loss_D_A_real: 0.012 loss_D_B_fake: 0.061 loss_D_B_real: 0.041
# Epoch[1](1360/2551) loss_PG: 16.819 loss_G_identity: 0.269 loss_G_GAN: 15.1 loss_G_recycle: 0.907 loss_D: 2.283
# loss_recurrent: 0.542 loss_D_A_fake: 0.518 loss_D_A_real: 1.960 loss_D_B_fake: 0.047 loss_D_B_real: 2.042
# Epoch[1](1380/2551) loss_PG: 19.648 loss_G_identity: 0.335 loss_G_GAN: 17.8 loss_G_recycle: 1.015 loss_D: 0.500
# loss_recurrent: 0.534 loss_D_A_fake: 0.147 loss_D_A_real: 0.039 loss_D_B_fake: 0.058 loss_D_B_real: 0.755
# Epoch[1](1400/2551) loss_PG: 10.233 loss_G_identity: 0.337 loss_G_GAN: 8.42 loss_G_recycle: 0.932 loss_D: 0.796
# loss_recurrent: 0.542 loss_D_A_fake: 0.213 loss_D_A_real: 0.321 loss_D_B_fake: 0.913 loss_D_B_real: 0.145
# Epoch[1](1420/2551) loss_PG: 13.258 loss_G_identity: 0.338 loss_G_GAN: 11.5 loss_G_recycle: 0.983 loss_D: 1.318
# loss_recurrent: 0.465 loss_D_A_fake: 0.655 loss_D_A_real: 0.090 loss_D_B_fake: 0.086 loss_D_B_real: 1.804
# Epoch[1](1440/2551) loss_PG: 12.760 loss_G_identity: 0.263 loss_G_GAN: 11.3 loss_G_recycle: 0.731 loss_D: 1.246
# loss_recurrent: 0.445 loss_D_A_fake: 0.262 loss_D_A_real: 1.101 loss_D_B_fake: 0.519 loss_D_B_real: 0.609
# Epoch[1](1460/2551) loss_PG: 15.623 loss_G_identity: 0.283 loss_G_GAN: 14.1 loss_G_recycle: 0.802 loss_D: 0.620
# loss_recurrent: 0.433 loss_D_A_fake: 0.255 loss_D_A_real: 0.763 loss_D_B_fake: 0.164 loss_D_B_real: 0.059
# Epoch[1](1480/2551) loss_PG: 11.615 loss_G_identity: 0.280 loss_G_GAN: 10.0 loss_G_recycle: 0.773 loss_D: 1.133
# loss_recurrent: 0.549 loss_D_A_fake: 0.121 loss_D_A_real: 1.043 loss_D_B_fake: 0.917 loss_D_B_real: 0.185
# Epoch[1](1500/2551) loss_PG: 12.621 loss_G_identity: 0.277 loss_G_GAN: 11.1 loss_G_recycle: 0.776 loss_D: 0.516
# loss_recurrent: 0.508 loss_D_A_fake: 0.065 loss_D_A_real: 0.016 loss_D_B_fake: 0.372 loss_D_B_real: 0.578
# Epoch[1](1520/2551) loss_PG: 7.745 loss_G_identity: 0.220 loss_G_GAN: 6.42 loss_G_recycle: 0.663 loss_D: 1.227
# loss_recurrent: 0.445 loss_D_A_fake: 0.631 loss_D_A_real: 0.554 loss_D_B_fake: 0.546 loss_D_B_real: 0.723
# Epoch[1](1540/2551) loss_PG: 20.168 loss_G_identity: 0.288 loss_G_GAN: 18.6 loss_G_recycle: 0.830 loss_D: 0.276
# loss_recurrent: 0.462 loss_D_A_fake: 0.080 loss_D_A_real: 0.215 loss_D_B_fake: 0.085 loss_D_B_real: 0.172
# Epoch[1](1560/2551) loss_PG: 18.978 loss_G_identity: 0.305 loss_G_GAN: 17.5 loss_G_recycle: 0.782 loss_D: 0.660
# loss_recurrent: 0.418 loss_D_A_fake: 0.011 loss_D_A_real: 0.112 loss_D_B_fake: 0.567 loss_D_B_real: 0.630
# Epoch[1](1580/2551) loss_PG: 7.785 loss_G_identity: 0.296 loss_G_GAN: 6.34 loss_G_recycle: 0.730 loss_D: 0.923
# loss_recurrent: 0.415 loss_D_A_fake: 0.802 loss_D_A_real: 0.164 loss_D_B_fake: 0.742 loss_D_B_real: 0.136
# Epoch[1](1600/2551) loss_PG: 14.728 loss_G_identity: 0.259 loss_G_GAN: 13.3 loss_G_recycle: 0.739 loss_D: 0.829
# loss_recurrent: 0.406 loss_D_A_fake: 0.132 loss_D_A_real: 0.512 loss_D_B_fake: 0.286 loss_D_B_real: 0.729
# Epoch[1](1620/2551) loss_PG: 11.577 loss_G_identity: 0.264 loss_G_GAN: 10.2 loss_G_recycle: 0.716 loss_D: 1.456
# loss_recurrent: 0.424 loss_D_A_fake: 1.014 loss_D_A_real: 0.203 loss_D_B_fake: 0.266 loss_D_B_real: 1.431
# Epoch[1](1640/2551) loss_PG: 12.905 loss_G_identity: 0.274 loss_G_GAN: 11.4 loss_G_recycle: 0.763 loss_D: 0.660
# loss_recurrent: 0.492 loss_D_A_fake: 0.224 loss_D_A_real: 0.019 loss_D_B_fake: 0.176 loss_D_B_real: 0.899
# Epoch[1](1660/2551) loss_PG: 18.158 loss_G_identity: 0.307 loss_G_GAN: 16.4 loss_G_recycle: 0.913 loss_D: 0.614
# loss_recurrent: 0.569 loss_D_A_fake: 0.055 loss_D_A_real: 0.062 loss_D_B_fake: 1.053 loss_D_B_real: 0.057
# Epoch[1](1680/2551) loss_PG: 15.136 loss_G_identity: 0.327 loss_G_GAN: 13.3 loss_G_recycle: 0.895 loss_D: 1.572
# loss_recurrent: 0.565 loss_D_A_fake: 0.084 loss_D_A_real: 2.214 loss_D_B_fake: 0.765 loss_D_B_real: 0.081
# Epoch[1](1700/2551) loss_PG: 12.016 loss_G_identity: 0.241 loss_G_GAN: 10.6 loss_G_recycle: 0.757 loss_D: 1.056
# loss_recurrent: 0.406 loss_D_A_fake: 0.716 loss_D_A_real: 0.002 loss_D_B_fake: 0.333 loss_D_B_real: 1.062
# Epoch[1](1720/2551) loss_PG: 23.971 loss_G_identity: 0.316 loss_G_GAN: 22.1 loss_G_recycle: 0.919 loss_D: 0.117
# loss_recurrent: 0.592 loss_D_A_fake: 0.008 loss_D_A_real: 0.159 loss_D_B_fake: 0.043 loss_D_B_real: 0.024
# Epoch[1](1740/2551) loss_PG: 20.310 loss_G_identity: 0.279 loss_G_GAN: 18.7 loss_G_recycle: 0.796 loss_D: 0.270
# loss_recurrent: 0.537 loss_D_A_fake: 0.141 loss_D_A_real: 0.000 loss_D_B_fake: 0.063 loss_D_B_real: 0.337
# Epoch[1](1760/2551) loss_PG: 12.154 loss_G_identity: 0.289 loss_G_GAN: 10.7 loss_G_recycle: 0.849 loss_D: 0.511
# loss_recurrent: 0.363 loss_D_A_fake: 0.557 loss_D_A_real: 0.076 loss_D_B_fake: 0.129 loss_D_B_real: 0.260
# Epoch[1](1780/2551) loss_PG: 15.121 loss_G_identity: 0.324 loss_G_GAN: 13.6 loss_G_recycle: 0.823 loss_D: 1.458
# loss_recurrent: 0.385 loss_D_A_fake: 0.676 loss_D_A_real: 0.052 loss_D_B_fake: 0.057 loss_D_B_real: 2.131
# Epoch[1](1800/2551) loss_PG: 14.893 loss_G_identity: 0.290 loss_G_GAN: 13.4 loss_G_recycle: 0.741 loss_D: 0.890
# loss_recurrent: 0.479 loss_D_A_fake: 0.191 loss_D_A_real: 1.383 loss_D_B_fake: 0.113 loss_D_B_real: 0.093
# ...
# loss_recurrent: 0.520 loss_D_A_fake: 0.141 loss_D_A_real: 0.000 loss_D_B_fake: 0.179 loss_D_B_real: 0.205
# Epoch[16](1560/2551) loss_PG: 13.423 loss_G_identity: 0.271 loss_G_GAN: 12.0 loss_G_recycle: 0.722 loss_D: 0.322
# loss_recurrent: 0.433 loss_D_A_fake: 0.227 loss_D_A_real: 0.042 loss_D_B_fake: 0.362 loss_D_B_real: 0.013
# Epoch[16](1580/2551) loss_PG: 18.119 loss_G_identity: 0.358 loss_G_GAN: 16.7 loss_G_recycle: 0.667 loss_D: 0.489
# loss_recurrent: 0.443 loss_D_A_fake: 0.195 loss_D_A_real: 0.003 loss_D_B_fake: 0.233 loss_D_B_real: 0.548
# Epoch[16](1600/2551) loss_PG: 24.526 loss_G_identity: 0.246 loss_G_GAN: 23.2 loss_G_recycle: 0.677 loss_D: 1.057
# loss_recurrent: 0.432 loss_D_A_fake: 0.022 loss_D_A_real: 0.033 loss_D_B_fake: 0.078 loss_D_B_real: 1.981
# Epoch[16](1620/2551) loss_PG: 16.139 loss_G_identity: 0.254 loss_G_GAN: 14.8 loss_G_recycle: 0.689 loss_D: 1.002
# loss_recurrent: 0.414 loss_D_A_fake: 0.574 loss_D_A_real: 0.003 loss_D_B_fake: 0.030 loss_D_B_real: 1.398
# Epoch[16](1640/2551) loss_PG: 15.463 loss_G_identity: 0.231 loss_G_GAN: 14.3 loss_G_recycle: 0.626 loss_D: 0.535
# loss_recurrent: 0.351 loss_D_A_fake: 0.286 loss_D_A_real: 0.607 loss_D_B_fake: 0.057 loss_D_B_real: 0.119
# Epoch[16](1660/2551) loss_PG: 17.847 loss_G_identity: 0.256 loss_G_GAN: 16.6 loss_G_recycle: 0.655 loss_D: 0.152
# loss_recurrent: 0.353 loss_D_A_fake: 0.037 loss_D_A_real: 0.055 loss_D_B_fake: 0.028 loss_D_B_real: 0.184
# Epoch[16](1680/2551) loss_PG: 23.902 loss_G_identity: 0.370 loss_G_GAN: 22.4 loss_G_recycle: 0.721 loss_D: 0.662
# loss_recurrent: 0.370 loss_D_A_fake: 0.087 loss_D_A_real: 0.909 loss_D_B_fake: 0.125 loss_D_B_real: 0.203
# Epoch[16](1700/2551) loss_PG: 13.793 loss_G_identity: 0.219 loss_G_GAN: 12.6 loss_G_recycle: 0.583 loss_D: 0.912
# loss_recurrent: 0.413 loss_D_A_fake: 0.214 loss_D_A_real: 1.170 loss_D_B_fake: 0.432 loss_D_B_real: 0.007
# Epoch[16](1720/2551) loss_PG: 22.936 loss_G_identity: 0.268 loss_G_GAN: 21.3 loss_G_recycle: 0.771 loss_D: 0.125
# loss_recurrent: 0.608 loss_D_A_fake: 0.136 loss_D_A_real: 0.069 loss_D_B_fake: 0.037 loss_D_B_real: 0.007
# Epoch[16](1740/2551) loss_PG: 14.133 loss_G_identity: 0.226 loss_G_GAN: 12.9 loss_G_recycle: 0.655 loss_D: 0.406
# loss_recurrent: 0.395 loss_D_A_fake: 0.462 loss_D_A_real: 0.002 loss_D_B_fake: 0.164 loss_D_B_real: 0.184
# Epoch[16](1760/2551) loss_PG: 22.230 loss_G_identity: 0.227 loss_G_GAN: 21.1 loss_G_recycle: 0.558 loss_D: 2.203
# loss_recurrent: 0.366 loss_D_A_fake: 0.129 loss_D_A_real: 2.134 loss_D_B_fake: 0.247 loss_D_B_real: 1.895
# Epoch[16](1780/2551) loss_PG: 19.587 loss_G_identity: 0.246 loss_G_GAN: 18.1 loss_G_recycle: 0.752 loss_D: 1.034
# loss_recurrent: 0.535 loss_D_A_fake: 0.675 loss_D_A_real: 0.004 loss_D_B_fake: 0.063 loss_D_B_real: 1.326
# Epoch[16](1800/2551) loss_PG: 15.252 loss_G_identity: 0.323 loss_G_GAN: 13.8 loss_G_recycle: 0.682 loss_D: 0.829
# loss_recurrent: 0.445 loss_D_A_fake: 0.306 loss_D_A_real: 0.004 loss_D_B_fake: 0.216 loss_D_B_real: 1.132
# Epoch[16](1820/2551) loss_PG: 6.344 loss_G_identity: 0.240 loss_G_GAN: 5.05 loss_G_recycle: 0.652 loss_D: 1.165
# loss_recurrent: 0.402 loss_D_A_fake: 1.529 loss_D_A_real: 0.365 loss_D_B_fake: 0.432 loss_D_B_real: 0.004
# Epoch[16](1840/2551) loss_PG: 13.269 loss_G_identity: 0.230 loss_G_GAN: 11.9 loss_G_recycle: 0.680 loss_D: 0.521
# loss_recurrent: 0.474 loss_D_A_fake: 0.348 loss_D_A_real: 0.000 loss_D_B_fake: 0.036 loss_D_B_real: 0.658
# Epoch[16](1860/2551) loss_PG: 9.316 loss_G_identity: 0.239 loss_G_GAN: 8.13 loss_G_recycle: 0.586 loss_D: 0.504
# loss_recurrent: 0.364 loss_D_A_fake: 0.405 loss_D_A_real: 0.001 loss_D_B_fake: 0.322 loss_D_B_real: 0.281
# Epoch[16](1880/2551) loss_PG: 10.967 loss_G_identity: 0.224 loss_G_GAN: 9.78 loss_G_recycle: 0.572 loss_D: 0.728
# loss_recurrent: 0.388 loss_D_A_fake: 0.360 loss_D_A_real: 0.740 loss_D_B_fake: 0.041 loss_D_B_real: 0.316
# Epoch[16](1900/2551) loss_PG: 9.331 loss_G_identity: 0.267 loss_G_GAN: 7.97 loss_G_recycle: 0.701 loss_D: 0.709
# loss_recurrent: 0.394 loss_D_A_fake: 0.201 loss_D_A_real: 1.091 loss_D_B_fake: 0.125 loss_D_B_real: 0.001
# Epoch[16](1920/2551) loss_PG: 17.205 loss_G_identity: 0.236 loss_G_GAN: 16.0 loss_G_recycle: 0.595 loss_D: 1.215
# loss_recurrent: 0.389 loss_D_A_fake: 0.048 loss_D_A_real: 1.728 loss_D_B_fake: 0.370 loss_D_B_real: 0.285
# Epoch[16](1940/2551) loss_PG: 21.880 loss_G_identity: 0.312 loss_G_GAN: 20.2 loss_G_recycle: 0.829 loss_D: 1.512
# loss_recurrent: 0.554 loss_D_A_fake: 0.088 loss_D_A_real: 2.659 loss_D_B_fake: 0.277 loss_D_B_real: 0.000
# Epoch[16](1960/2551) loss_PG: 17.281 loss_G_identity: 0.236 loss_G_GAN: 15.9 loss_G_recycle: 0.669 loss_D: 1.341
# loss_recurrent: 0.488 loss_D_A_fake: 0.282 loss_D_A_real: 0.759 loss_D_B_fake: 0.124 loss_D_B_real: 1.517
# Epoch[16](1980/2551) loss_PG: 9.894 loss_G_identity: 0.234 loss_G_GAN: 8.62 loss_G_recycle: 0.651 loss_D: 0.869
# loss_recurrent: 0.385 loss_D_A_fake: 0.497 loss_D_A_real: 0.002 loss_D_B_fake: 0.500 loss_D_B_real: 0.739
# Epoch[16](2000/2551) loss_PG: 29.116 loss_G_identity: 0.272 loss_G_GAN: 27.6 loss_G_recycle: 0.757 loss_D: 1.244
# loss_recurrent: 0.455 loss_D_A_fake: 0.158 loss_D_A_real: 2.121 loss_D_B_fake: 0.163 loss_D_B_real: 0.045
# Epoch[16](2020/2551) loss_PG: 18.929 loss_G_identity: 0.272 loss_G_GAN: 17.5 loss_G_recycle: 0.713 loss_D: 1.008
# loss_recurrent: 0.421 loss_D_A_fake: 0.542 loss_D_A_real: 0.007 loss_D_B_fake: 0.023 loss_D_B_real: 1.445
# Epoch[16](2040/2551) loss_PG: 19.065 loss_G_identity: 0.271 loss_G_GAN: 17.7 loss_G_recycle: 0.692 loss_D: 0.389
# loss_recurrent: 0.353 loss_D_A_fake: 0.095 loss_D_A_real: 0.143 loss_D_B_fake: 0.345 loss_D_B_real: 0.195
# Epoch[16](2060/2551) loss_PG: 17.825 loss_G_identity: 0.268 loss_G_GAN: 16.5 loss_G_recycle: 0.691 loss_D: 0.371
# loss_recurrent: 0.370 loss_D_A_fake: 0.224 loss_D_A_real: 0.034 loss_D_B_fake: 0.121 loss_D_B_real: 0.363
# Epoch[16](2080/2551) loss_PG: 17.136 loss_G_identity: 0.262 loss_G_GAN: 15.4 loss_G_recycle: 0.867 loss_D: 0.208
# loss_recurrent: 0.620 loss_D_A_fake: 0.115 loss_D_A_real: 0.008 loss_D_B_fake: 0.245 loss_D_B_real: 0.048
# Epoch[16](2100/2551) loss_PG: 19.994 loss_G_identity: 0.246 loss_G_GAN: 18.7 loss_G_recycle: 0.655 loss_D: 0.207
# loss_recurrent: 0.378 loss_D_A_fake: 0.114 loss_D_A_real: 0.124 loss_D_B_fake: 0.048 loss_D_B_real: 0.129
# Epoch[16](2120/2551) loss_PG: 18.990 loss_G_identity: 0.292 loss_G_GAN: 17.6 loss_G_recycle: 0.705 loss_D: 1.255
# loss_recurrent: 0.438 loss_D_A_fake: 0.071 loss_D_A_real: 2.009 loss_D_B_fake: 0.072 loss_D_B_real: 0.358
# Epoch[16](2140/2551) loss_PG: 10.794 loss_G_identity: 0.237 loss_G_GAN: 9.53 loss_G_recycle: 0.637 loss_D: 0.567
# loss_recurrent: 0.389 loss_D_A_fake: 0.662 loss_D_A_real: 0.038 loss_D_B_fake: 0.237 loss_D_B_real: 0.197
# Epoch[16](2160/2551) loss_PG: 17.058 loss_G_identity: 0.226 loss_G_GAN: 15.9 loss_G_recycle: 0.626 loss_D: 0.642
# loss_recurrent: 0.352 loss_D_A_fake: 0.283 loss_D_A_real: 0.018 loss_D_B_fake: 0.048 loss_D_B_real: 0.936
# Epoch[16](2180/2551) loss_PG: 17.236 loss_G_identity: 0.290 loss_G_GAN: 15.7 loss_G_recycle: 0.720 loss_D: 0.265
# loss_recurrent: 0.547 loss_D_A_fake: 0.271 loss_D_A_real: 0.025 loss_D_B_fake: 0.229 loss_D_B_real: 0.004
# Epoch[16](2200/2551) loss_PG: 14.107 loss_G_identity: 0.226 loss_G_GAN: 12.9 loss_G_recycle: 0.643 loss_D: 0.958
# loss_recurrent: 0.359 loss_D_A_fake: 0.881 loss_D_A_real: 0.757 loss_D_B_fake: 0.081 loss_D_B_real: 0.198
# Epoch[16](2220/2551) loss_PG: 13.331 loss_G_identity: 0.280 loss_G_GAN: 11.8 loss_G_recycle: 0.767 loss_D: 0.690
# loss_recurrent: 0.525 loss_D_A_fake: 0.054 loss_D_A_real: 0.960 loss_D_B_fake: 0.360 loss_D_B_real: 0.007
# Epoch[16](2240/2551) loss_PG: 8.113 loss_G_identity: 0.272 loss_G_GAN: 6.77 loss_G_recycle: 0.681 loss_D: 1.234
# loss_recurrent: 0.387 loss_D_A_fake: 0.542 loss_D_A_real: 1.216 loss_D_B_fake: 0.431 loss_D_B_real: 0.279
# Epoch[16](2260/2551) loss_PG: 15.538 loss_G_identity: 0.342 loss_G_GAN: 13.9 loss_G_recycle: 0.831 loss_D: 1.526
# loss_recurrent: 0.475 loss_D_A_fake: 0.083 loss_D_A_real: 2.357 loss_D_B_fake: 0.559 loss_D_B_real: 0.053
# Epoch[16](2280/2551) loss_PG: 33.473 loss_G_identity: 0.241 loss_G_GAN: 32.2 loss_G_recycle: 0.637 loss_D: 1.144
# loss_recurrent: 0.354 loss_D_A_fake: 0.150 loss_D_A_real: 0.122 loss_D_B_fake: 0.206 loss_D_B_real: 1.812
# Epoch[16](2300/2551) loss_PG: 5.088 loss_G_identity: 0.256 loss_G_GAN: 3.84 loss_G_recycle: 0.638 loss_D: 1.043
# loss_recurrent: 0.358 loss_D_A_fake: 1.333 loss_D_A_real: 0.148 loss_D_B_fake: 0.603 loss_D_B_real: 0.001
# Epoch[16](2320/2551) loss_PG: 24.902 loss_G_identity: 0.301 loss_G_GAN: 23.3 loss_G_recycle: 0.803 loss_D: 0.129
# loss_recurrent: 0.519 loss_D_A_fake: 0.101 loss_D_A_real: 0.014 loss_D_B_fake: 0.018 loss_D_B_real: 0.125
# Epoch[16](2340/2551) loss_PG: 16.303 loss_G_identity: 0.274 loss_G_GAN: 14.8 loss_G_recycle: 0.773 loss_D: 1.721
# loss_recurrent: 0.434 loss_D_A_fake: 0.051 loss_D_A_real: 3.103 loss_D_B_fake: 0.255 loss_D_B_real: 0.032
# Epoch[16](2360/2551) loss_PG: 15.529 loss_G_identity: 0.300 loss_G_GAN: 14.0 loss_G_recycle: 0.775 loss_D: 0.720
# loss_recurrent: 0.470 loss_D_A_fake: 1.065 loss_D_A_real: 0.294 loss_D_B_fake: 0.065 loss_D_B_real: 0.017
# Epoch[16](2380/2551) loss_PG: 13.656 loss_G_identity: 0.345 loss_G_GAN: 11.8 loss_G_recycle: 0.955 loss_D: 0.308
# loss_recurrent: 0.523 loss_D_A_fake: 0.364 loss_D_A_real: 0.010 loss_D_B_fake: 0.086 loss_D_B_real: 0.155
# Epoch[16](2400/2551) loss_PG: 18.219 loss_G_identity: 0.210 loss_G_GAN: 17.0 loss_G_recycle: 0.575 loss_D: 1.303
# loss_recurrent: 0.412 loss_D_A_fake: 0.272 loss_D_A_real: 1.111 loss_D_B_fake: 0.029 loss_D_B_real: 1.194
# Epoch[16](2420/2551) loss_PG: 10.372 loss_G_identity: 0.233 loss_G_GAN: 9.2 loss_G_recycle: 0.557 loss_D: 1.237
# loss_recurrent: 0.379 loss_D_A_fake: 0.448 loss_D_A_real: 0.982 loss_D_B_fake: 0.725 loss_D_B_real: 0.318
# Epoch[16](2440/2551) loss_PG: 11.516 loss_G_identity: 0.245 loss_G_GAN: 10.3 loss_G_recycle: 0.614 loss_D: 1.009
# loss_recurrent: 0.336 loss_D_A_fake: 0.213 loss_D_A_real: 0.058 loss_D_B_fake: 0.052 loss_D_B_real: 1.695
# Epoch[16](2460/2551) loss_PG: 17.718 loss_G_identity: 0.209 loss_G_GAN: 16.6 loss_G_recycle: 0.560 loss_D: 1.433
# loss_recurrent: 0.385 loss_D_A_fake: 0.389 loss_D_A_real: 1.066 loss_D_B_fake: 0.031 loss_D_B_real: 1.379
# Epoch[16](2480/2551) loss_PG: 30.016 loss_G_identity: 0.283 loss_G_GAN: 28.4 loss_G_recycle: 0.760 loss_D: 0.036
# loss_recurrent: 0.528 loss_D_A_fake: 0.002 loss_D_A_real: 0.003 loss_D_B_fake: 0.053 loss_D_B_real: 0.014
# Epoch[16](2500/2551) loss_PG: 23.594 loss_G_identity: 0.409 loss_G_GAN: 22.2 loss_G_recycle: 0.633 loss_D: 1.476
# loss_recurrent: 0.382 loss_D_A_fake: 0.102 loss_D_A_real: 2.331 loss_D_B_fake: 0.469 loss_D_B_real: 0.050
# Epoch[16](2520/2551) loss_PG: 10.614 loss_G_identity: 0.282 loss_G_GAN: 9.15 loss_G_recycle: 0.748 loss_D: 0.598
# loss_recurrent: 0.430 loss_D_A_fake: 0.938 loss_D_A_real: 0.044 loss_D_B_fake: 0.140 loss_D_B_real: 0.074
# Epoch[16](2540/2551) loss_PG: 17.184 loss_G_identity: 0.317 loss_G_GAN: 15.6 loss_G_recycle: 0.787 loss_D: 0.865
# loss_recurrent: 0.437 loss_D_A_fake: 0.269 loss_D_A_real: 1.209 loss_D_B_fake: 0.112 loss_D_B_real: 0.140
# Epoch[17](0/2551) loss_PG: 15.908 loss_G_identity: 0.306 loss_G_GAN: 14.4 loss_G_recycle: 0.725 loss_D: 0.655
# loss_recurrent: 0.469 loss_D_A_fake: 0.097 loss_D_A_real: 1.105 loss_D_B_fake: 0.080 loss_D_B_real: 0.028
# Epoch[17](20/2551) loss_PG: 15.448 loss_G_identity: 0.246 loss_G_GAN: 14.2 loss_G_recycle: 0.658 loss_D: 0.484
# loss_recurrent: 0.336 loss_D_A_fake: 0.174 loss_D_A_real: 0.023 loss_D_B_fake: 0.278 loss_D_B_real: 0.492
# Epoch[17](40/2551) loss_PG: 9.542 loss_G_identity: 0.241 loss_G_GAN: 8.25 loss_G_recycle: 0.634 loss_D: 0.864
# loss_recurrent: 0.412 loss_D_A_fake: 0.351 loss_D_A_real: 0.140 loss_D_B_fake: 0.509 loss_D_B_real: 0.729
# Epoch[17](60/2551) loss_PG: 14.344 loss_G_identity: 0.219 loss_G_GAN: 13.2 loss_G_recycle: 0.540 loss_D: 1.485
# loss_recurrent: 0.375 loss_D_A_fake: 1.321 loss_D_A_real: 0.308 loss_D_B_fake: 0.135 loss_D_B_real: 1.205
# Epoch[17](80/2551) loss_PG: 12.421 loss_G_identity: 0.241 loss_G_GAN: 11.1 loss_G_recycle: 0.698 loss_D: 0.835
# loss_recurrent: 0.421 loss_D_A_fake: 0.111 loss_D_A_real: 0.003 loss_D_B_fake: 1.246 loss_D_B_real: 0.310
# Epoch[17](100/2551) loss_PG: 8.038 loss_G_identity: 0.214 loss_G_GAN: 6.81 loss_G_recycle: 0.596 loss_D: 1.348
# loss_recurrent: 0.421 loss_D_A_fake: 0.341 loss_D_A_real: 1.301 loss_D_B_fake: 1.031 loss_D_B_real: 0.025
# Epoch[17](120/2551) loss_PG: 24.419 loss_G_identity: 0.287 loss_G_GAN: 22.9 loss_G_recycle: 0.764 loss_D: 1.873
# loss_recurrent: 0.426 loss_D_A_fake: 0.067 loss_D_A_real: 3.306 loss_D_B_fake: 0.264 loss_D_B_real: 0.110
# Epoch[17](140/2551) loss_PG: 15.180 loss_G_identity: 0.278 loss_G_GAN: 13.3 loss_G_recycle: 0.876 loss_D: 0.358
# loss_recurrent: 0.686 loss_D_A_fake: 0.087 loss_D_A_real: 0.035 loss_D_B_fake: 0.589 loss_D_B_real: 0.005
# Epoch[17](160/2551) loss_PG: 18.325 loss_G_identity: 0.262 loss_G_GAN: 16.9 loss_G_recycle: 0.745 loss_D: 0.269
# loss_recurrent: 0.431 loss_D_A_fake: 0.486 loss_D_A_real: 0.036 loss_D_B_fake: 0.013 loss_D_B_real: 0.003
# Epoch[17](180/2551) loss_PG: 13.622 loss_G_identity: 0.226 loss_G_GAN: 12.2 loss_G_recycle: 0.669 loss_D: 1.498
# loss_recurrent: 0.502 loss_D_A_fake: 0.034 loss_D_A_real: 2.385 loss_D_B_fake: 0.568 loss_D_B_real: 0.008
# Epoch[17](200/2551) loss_PG: 17.060 loss_G_identity: 0.255 loss_G_GAN: 15.6 loss_G_recycle: 0.719 loss_D: 0.108
# loss_recurrent: 0.456 loss_D_A_fake: 0.047 loss_D_A_real: 0.021 loss_D_B_fake: 0.146 loss_D_B_real: 0.002
# Epoch[17](220/2551) loss_PG: 12.790 loss_G_identity: 0.212 loss_G_GAN: 11.7 loss_G_recycle: 0.577 loss_D: 1.070
# loss_recurrent: 0.346 loss_D_A_fake: 0.155 loss_D_A_real: 1.406 loss_D_B_fake: 0.574 loss_D_B_real: 0.006
# Epoch[17](240/2551) loss_PG: 23.102 loss_G_identity: 0.303 loss_G_GAN: 21.6 loss_G_recycle: 0.799 loss_D: 0.121
# loss_recurrent: 0.374 loss_D_A_fake: 0.117 loss_D_A_real: 0.056 loss_D_B_fake: 0.013 loss_D_B_real: 0.057
# Epoch[17](260/2551) loss_PG: 17.564 loss_G_identity: 0.257 loss_G_GAN: 15.9 loss_G_recycle: 0.794 loss_D: 0.290
# loss_recurrent: 0.603 loss_D_A_fake: 0.079 loss_D_A_real: 0.032 loss_D_B_fake: 0.465 loss_D_B_real: 0.004
# Epoch[17](280/2551) loss_PG: 17.824 loss_G_identity: 0.288 loss_G_GAN: 16.4 loss_G_recycle: 0.721 loss_D: 0.787
# loss_recurrent: 0.377 loss_D_A_fake: 0.148 loss_D_A_real: 0.009 loss_D_B_fake: 0.108 loss_D_B_real: 1.310
# Epoch[17](300/2551) loss_PG: 19.436 loss_G_identity: 0.285 loss_G_GAN: 17.8 loss_G_recycle: 0.776 loss_D: 0.277
# loss_recurrent: 0.567 loss_D_A_fake: 0.283 loss_D_A_real: 0.002 loss_D_B_fake: 0.238 loss_D_B_real: 0.032
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-c2b7ef383f22> in <module>()
#      72         loss_PG.backward()
#      73
# ---> 74         optimizer_PG.step()
#      75
#      76         # 保存用画像のための処理
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py in wrapper(*args, **kwargs)
#      65                 instance._step_count += 1
#      66                 wrapped = func.__get__(instance, cls)
# ---> 67                 return wrapped(*args, **kwargs)
#      68
#      69             # Note that the returned function here is no longer a bound method,
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      13         def decorate_context(*args, **kwargs):
#      14             with self:
# ---> 15                 return func(*args, **kwargs)
#      16         return decorate_context
#      17
#
# /usr/local/lib/python3.6/dist-packages/torch/optim/adam.py in step(self, closure)
#      97
#      98                 # Decay the first and second moment running average coefficient
# ---> 99                 exp_avg.mul_(beta1).add_(grad, alpha=1 - beta1)
#     100                 exp_avg_sq.mul_(beta2).addcmul_(grad, grad, value=1 - beta2)
#     101                 if amsgrad:
#
# KeyboardInterrupt:

# %%
# !ls output
# Out:
# netD_A.pth  netD_B.pth	netG_A2B.pth  netG_B2A.pth

# %% [markdown]
# # 画像生成テスト

# %% [markdown]
# ## パラメータ設定

# %%
class Opts_test():
    def __init__(self):
        self.batch_size = 1
        self.dataroot = 'datasets/'
        self.size = 256
        self.input_nc = 3
        self.output_nc = 3
        self.cpu = False
        self.n_cpu = 8
        self.device_name = "cuda:0"
        self.device = torch.device(self.device_name)
        self.load_weight = True
        self.cuda = True
        self.model_load_path = 'output/recycle/train11/output_model/'
        self.log_base_name = 'test01'
        self.file_a_dir = 'fadg0/video/'
        self.file_b_dir = 'faks0/video/'
        self.skip = 2

opt2 = Opts_test()

# %% [markdown]
# ## ネットワーク呼び出し

# %%
# 生成器G
netG_A2B = Generator(opt2.input_nc, opt2.output_nc)
netG_B2A = Generator(opt2.output_nc, opt2.input_nc)

# 予測器 
netP_A = Predictor(opt.input_nc*2, opt.input_nc)
netP_B = Predictor(opt.output_nc*2, opt.output_nc)


# CUDA
if opt2.cuda:
    netG_A2B.cuda()
    netG_B2A.cuda()
    netP_A.cuda() # predictor
    netP_B.cuda() # predictor

# Load state dicts
netG_A2B.load_state_dict(torch.load(os.path.join(opt2.model_load_path, 'netG_A2B.pth')))
netG_B2A.load_state_dict(torch.load(os.path.join(opt2.model_load_path, 'netG_B2A.pth')))
netP_A.load_state_dict(torch.load(os.path.join(opt.model_load_path, "netP_A.pth"), map_location="cuda:0"), strict=False) # predictor
netP_B.load_state_dict(torch.load(os.path.join(opt.model_load_path, "netP_B.pth"), map_location="cuda:0"), strict=False) # predictor

# Set model's test mode
netG_A2B.eval()
netG_B2A.eval()
netP_A.eval()
netP_B.eval()

# Inputs & targets memory allocation
Tensor = torch.cuda.FloatTensor if opt2.cuda else torch.Tensor
input_A1 = Tensor(opt.batch_size, opt.input_nc, opt.size, opt.size)
input_A2 = Tensor(opt.batch_size, opt.input_nc, opt.size, opt.size)
input_A3 = Tensor(opt.batch_size, opt.input_nc, opt.size, opt.size)
input_B1 = Tensor(opt.batch_size, opt.output_nc, opt.size, opt.size)
input_B2 = Tensor(opt.batch_size, opt.output_nc, opt.size, opt.size)
input_B3 = Tensor(opt.batch_size, opt.output_nc, opt.size, opt.size)

# Dataset loader
transforms_ = [transforms.Resize(int(opt2.size*1.0), Image.BICUBIC), 
                transforms.RandomCrop(opt2.size), 
                transforms.ToTensor(),
                transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5)) ]
dataloader = DataLoader(FaceDatasetSequence(opt.dataroot, transforms_=transforms_, unaligned=False, 
                                            files_A=opt2.file_a_dir, files_B=opt2.file_b_dir, skip=opt.skip), 
                        batch_size=opt.batch_size, shuffle=True, num_workers=opt.n_cpu)


# 出力用フォルダ生成
if not os.path.exists(os.path.join('output/recycle', opt2.log_base_name)):
    os.makedirs(os.path.join('output/recycle', opt2.log_base_name))
if not os.path.exists(os.path.join('output/recycle', opt2.log_base_name, 'output_img')):
    os.makedirs(os.path.join('output/recycle', opt2.log_base_name, 'output_img'))
if not os.path.exists(os.path.join('output/recycle', opt2.log_base_name, 'output_img/A')):
    os.makedirs(os.path.join('output/recycle', opt2.log_base_name, 'output_img/A'))
if not os.path.exists(os.path.join('output/recycle', opt2.log_base_name, 'output_img/B')):
    os.makedirs(os.path.join('output/recycle', opt2.log_base_name, 'output_img/B'))
# Out:
# len(self.files_A):2551, len(self.files_B):1969

# %% [markdown]
# ## テスト実行

# %%
##### 生成器Gによる画像生成　#####
from torchvision.utils import save_image

num_create = 100

for i, batch in enumerate(dataloader):
    # Set model input
    real_A1 = Variable(input_A1.copy_(batch['A1']))
    real_A2 = Variable(input_A2.copy_(batch['A2']))
    real_A3 = Variable(input_A3.copy_(batch['A3']))

    real_B1 = Variable(input_B1.copy_(batch['B1']))
    real_B2 = Variable(input_B2.copy_(batch['B2']))
    real_B3 = Variable(input_B3.copy_(batch['B3']))

    # Generate fake image
    fake_B1 = netG_A2B(real_A1)
    fake_B2 = netG_A2B(real_A2)
    fake_B3 = netG_A2B(real_A3)

    fake_A1 = netG_B2A(real_B1)
    fake_A2 = netG_B2A(real_B2)
    fake_A3 = netG_B2A(real_B3)

    # Predict next step
    fake_B12 = torch.cat((fake_B1, fake_B2), dim=1)
    fake_B3_pred = netP_B(fake_B12)

    fake_A12 = torch.cat((fake_A1, fake_A2), dim=1)
    fake_A3_pred = netP_B(fake_A12)

    # Calculate the average of fake and pred
    fake_B3_ave = (fake_B3 + fake_B3_pred) / 2.
    fake_A3_ave = (fake_A3 + fake_A3_pred) / 2.


    real_A1_out = 0.5*(real_A1 + 1.0)
    real_A2_out = 0.5*(real_A2 + 1.0)
    real_A3_out = 0.5*(real_A3 + 1.0)

    real_B1_out = 0.5*(real_B1 + 1.0)
    real_B2_out = 0.5*(real_B2 + 1.0)
    real_B3_out = 0.5*(real_B3 + 1.0)

    fake_A3_ave_out = 0.5*(fake_A3_ave + 1.0)
    fake_B3_ave_out = 0.5*(fake_B3_ave + 1.0)

    out_img1 = torch.cat([real_A3_out, fake_B3_ave_out], dim=2)
    out_img2 = torch.cat([real_B3_out, fake_A3_ave_out], dim=2)

    # Save image files
    save_image(out_img1, os.path.join('output/recycle/', opt2.log_base_name, 'output_img/A/%04d.png' % (i+1)))
    save_image(out_img2, os.path.join('output/recycle/', opt2.log_base_name, 'output_img/B/%04d.png' % (i+1)))

    if i > num_create:
        break

# %% [markdown]
# ## 生成画像の表示

# %%
# A->Bの生成画像
import matplotlib.pyplot as plt
img = plt.imread(os.path.join('output/recycle/', opt2.log_base_name, 'output_img/A/0001.png'))
plt.imshow(img)

# %%
# B->Aの生成画像
img = plt.imread(os.path.join('output/recycle/', opt2.log_base_name, 'output_img/B/0001.png'))
plt.imshow(img)

# %% [markdown]
# # ビデオ生成テスト

# %% [markdown]
# ## 動画出力用のデータセット生成

# %%
# 動画出力用のデータセット生成クラス
class FaceDatasetVideo(Dataset):
    def __init__(self, root, transforms_=None, unaligned=False, mode='train', 
                 files='fadg0/video/head', skip=2):
        self.skip = skip
        self.remove_num = (skip + 1) * 2
        self.transform = transforms.Compose(transforms_)
        self.unaligned = unaligned
        all_files = sorted(glob.glob(os.path.join(root, files) + '/*'))
        self.files = all_files[:-self.remove_num]

    def __getitem__(self, index):
        file = self.files[index % len(self.files)]
        seed = 1234
        item_1, item_2, item_3 = self.get_sequential_data(file, seed)
        return {'1': item_1, '2': item_2, '3' : item_3}

    def get_sequential_data(self, file1, seed):
        dir_name, file_num = file1.rsplit('/', 1)
        file2 = os.path.join(dir_name, '{:0=3}'.format(int(file_num) + self.skip))
        file3 = os.path.join(dir_name, '{:0=3}'.format(int(file_num) + self.skip * 2))
        random.seed(seed)
        item1 = self.transform(Image.open(file1).convert('RGB'))
        random.seed(seed)
        item2 = self.transform(Image.open(file2).convert('RGB'))
        random.seed(seed)
        item3 = self.transform(Image.open(file3).convert('RGB'))
        return item1, item2, item3
        
    def __len__(self):
        return len(self.files)

# %% [markdown]
# ## 動画出力の処理

# %%
# 動画出力用フォルダの生成
if not os.path.exists(os.path.join('output/recycle', opt2.log_base_name, 'output_video')):
    os.makedirs(os.path.join('output/recycle', opt2.log_base_name, 'output_video'))
if not os.path.exists(os.path.join('output/recycle', opt2.log_base_name, 'output_video/A2B')):
    os.makedirs(os.path.join('output/recycle', opt2.log_base_name, 'output_video/A2B'))
if not os.path.exists(os.path.join('output/recycle', opt2.log_base_name, 'output_video/B2A')):
    os.makedirs(os.path.join('output/recycle', opt2.log_base_name, 'output_video/B2A'))



# 動画のパラメータを設定
import cv2
in_video_w = 256*2
in_video_h = 256
fourcc = cv2.VideoWriter_fourcc('m', 'p', '4', 'v')

def make_video(output_video_path, input_dir_path, domain, skip=2):
    video = cv2.VideoWriter(output_video_path, fourcc, 10.0, (in_video_w, in_video_h))

    # ネットワーク呼び出し
    # 生成器G
    netG_A2B = Generator(opt2.input_nc, opt2.output_nc)
    netG_B2A = Generator(opt2.output_nc, opt2.input_nc)

    # 予測器 
    netP_A = Predictor(opt.input_nc*2, opt.input_nc)
    netP_B = Predictor(opt.output_nc*2, opt.output_nc)

    # CUDA
    if opt2.cuda:
        netG_A2B.cuda()
        netG_B2A.cuda()
        netP_A.cuda() # predictor
        netP_B.cuda() # predictor

    # Load state dicts
    netG_A2B.load_state_dict(torch.load(os.path.join(opt2.model_load_path, 'netG_A2B.pth')))
    netG_B2A.load_state_dict(torch.load(os.path.join(opt2.model_load_path, 'netG_B2A.pth')))
    netP_A.load_state_dict(torch.load(os.path.join(opt.model_load_path, "netP_A.pth"), map_location="cuda:0"), strict=False) # predictor
    netP_B.load_state_dict(torch.load(os.path.join(opt.model_load_path, "netP_B.pth"), map_location="cuda:0"), strict=False) # predictor

    # Set model's test mode
    netG_A2B.eval()
    netG_B2A.eval()
    netP_A.eval()
    netP_B.eval()

    # Inputs & targets memory allocation
    Tensor = torch.cuda.FloatTensor if opt2.cuda else torch.Tensor
    input_A1 = Tensor(opt.batch_size, opt.input_nc, opt.size, opt.size)
    input_A2 = Tensor(opt.batch_size, opt.input_nc, opt.size, opt.size)
    input_A3 = Tensor(opt.batch_size, opt.input_nc, opt.size, opt.size)
    input_B1 = Tensor(opt.batch_size, opt.output_nc, opt.size, opt.size)
    input_B2 = Tensor(opt.batch_size, opt.output_nc, opt.size, opt.size)
    input_B3 = Tensor(opt.batch_size, opt.output_nc, opt.size, opt.size)


    # Dataset loader
    transforms_ = [transforms.Resize(int(opt2.size*1.0), Image.BICUBIC), 
                    transforms.CenterCrop(opt2.size),
                    transforms.ToTensor(),
                    transforms.Normalize((0.5,0.5,0.5), (0.5,0.5,0.5)) ]
    dataloader = DataLoader(FaceDatasetVideo(opt2.dataroot, transforms_=transforms_, mode='test',
                            files=input_dir_path, skip=skip), 
                            batch_size=opt2.batch_size, shuffle=False, num_workers=opt2.n_cpu)
    
    ##### 生成器Gによる動画生成　#####
    for i, batch in enumerate(dataloader):
        if domain == 'A':
            # Set model input
            real_A1 = Variable(input_A1.copy_(batch['1']))
            real_A2 = Variable(input_A2.copy_(batch['2']))
            real_A3 = Variable(input_A3.copy_(batch['3']))

            # Generate output
            fake_B1 = netG_A2B(real_A1)
            fake_B2 = netG_A2B(real_A2)
            fake_B3 = netG_A2B(real_A3)

            fake_B12 = torch.cat((fake_B1, fake_B2), dim=1)
            fake_B3_pred = netP_B(fake_B12)

            # Calculate the average of fake and pred
            fake_B3_ave = (fake_B3 + fake_B3_pred) / 2.

            out_img1 = torch.cat([real_A3, fake_B3_ave], dim=3)
        else:
            # Set model input
            real_B1 = Variable(input_B1.copy_(batch['1']))
            real_B2 = Variable(input_B2.copy_(batch['2']))
            real_B3 = Variable(input_B3.copy_(batch['3']))

            # Generate output
            fake_A1 = netG_B2A(real_B1)
            fake_A2 = netG_B2A(real_B2)
            fake_A3 = netG_B2A(real_B3)

            fake_A12 = torch.cat((fake_A1, fake_A2), dim=1)
            fake_A3_pred = netP_A(fake_A12)

            # Calculate the average of fake and pred
            fake_A3_ave = (fake_A3 + fake_A3_pred) / 2.

            out_img1 = torch.cat([real_B3, fake_A3_ave], dim=3)

        image = 127.5 * (out_img1[0].cpu().float().detach().numpy() + 1.0)
        image = image.transpose(1,2,0).astype(np.uint8)
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        video.write(image)
    print("video saved!")

# %% [markdown]
# ## 動画を生成し、保存する

# %%
output_video_path = os.path.join('output/recycle/', opt2.log_base_name, 'output_video/A2B/head.mp4')
input_dir_path =  'fadg0/video/head'
domain = 'A'

make_video(output_video_path, input_dir_path, domain=domain)

# %%
output_video_path = os.path.join('output/recycle/', opt2.log_base_name, 'output_video/B2A/sa2.mp4')
input_dir_path =  'faks0/video/sa2'
domain = 'B'

make_video(output_video_path, input_dir_path, domain=domain)
# Out:
# video saved!
